# %% [markdown]
# ## 使用python库

# %%
# %matplotlib notebook

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import seaborn as sbn
sbn.set()

# %% [markdown]
# ## 参数

# %%
# Variable
timesteps = 32
batch_size = 4
units = 32
data_dim = 8
div_class = [-0.003, 0.003]
#div_class = [-0.5, -0.3, -0.1, 0.1, 0.3, 0.5]
num_classes = len(div_class) + 1

# %% [markdown]
# ## 数据处理

# %% [markdown]
# ### 数据加载

# %%
def data_load():
    data_dir = '../data/'
    day_index1 = data_dir + '1day/index/2000_2009.csv'
    day_index2 = data_dir + '1day/index/2010_2016.csv'
    data1 = pd.read_csv(day_index1,encoding='gbk', parse_dates=['date'])
    data2 = pd.read_csv(day_index2,encoding='gbk', parse_dates=['date'])
    data = pd.concat([data1, data2])
    data.set_index(['code', 'date'], inplace=True)
    return data

# %% [markdown]
# ### 数据分割

# %%
def get_data(data, timesteps, batch_size, query_str):
    match = data.query(query_str)
    min_num = int(batch_size) * int(timesteps) 
    size = len(match)
    m = int(size / min_num)
    if m < 1:
        return None
    
    end_num = min_num * m
    print("data set: {0}:{1} of {2}".format(0, end_num, size))
    result = match.iloc[:end_num, :].copy()

    return result

# %% [markdown]
# ### 数据清理

# %%
def data_clean(data):
    new_data = pd.DataFrame()
    for column in ['open', 'high', 'low', 'close']:
        new_data[column] = data[column] / 10000.0

    # new_data.dropna(inplace=True)
    return new_data

# %% [markdown]
# ### 数据转换

# %% [markdown]
# #### 转换函数

# %%
# 阴阳线
def stick_type(x):
    stick_type = -1
    if x['close'] >= x['open']:
        stick_type = 1
    return stick_type

# 上引线
def up_line(x):
    return x['high'] - x[['open','close']].max()

# 下引线
def down_line(x):
    return x[['open','close']].min() - x['low']

# 实体长度
def body_size(x):
    return x['close'] - x['open']

def range_to_class(x):
    cls = []
    size = len(div_class)
    n = -1;
    if x < div_class[0]:
        n = 1
    elif x >= div_class[size-1]:
        n = size + 1
    else:    
        for i in range(0, size-1):
            if div_class[i] <= x < div_class[i+1]:
                n = i + 2
                # print("n=", n)
                break
    if n >= 0:
        for i in range(0, size+1):
            if i == n - 1:
                cls.append(1.0)
            else:
                cls.append(0.0)
    else:
        print(x)
        print("Error: n less than 0")
    return cls

# %% [markdown]
# #### 数据转换

# %%
def data_transform(data):
    new_data = pd.DataFrame()
    pre_close = data['close'].shift(1)
    for column in ['open', 'high', 'low', 'close']:
        new_data[column] = (data[column] - pre_close) / pre_close
        
    # add new feature
    new_data['stick_type'] = new_data.apply(stick_type, axis=1)
    new_data['up_line'] = new_data.apply(up_line, axis=1)
    new_data['down_line'] = new_data.apply(down_line, axis=1)
    new_data['close_open'] = new_data.apply(body_size, axis=1)
        
    # classes
    new_data['class'] = new_data['close'].shift(-1)
    # new_data.dropna(inplace=True)
    new_data.fillna(0, inplace=True)
    new_data['class']= new_data['class'].map(range_to_class)
        
    # new_data.dropna(inplace=True)
    return new_data

# %% [markdown]
# ### 数据标准化

# %%
def normalize(data):
    columns = ['open', 'high', 'low', 'close', 'stick_type', 'up_line', 'down_line', 'close_open']
    for column in columns:
        data[column] = data[column] * 100
    return data

# %% [markdown]
# ### 数据重整

# %%
def data_reform(data, batch_size, timesteps):
    print("shape: {0}".format(data.shape))
    size = len(data)
    if size % (int(batch_size) * int(timesteps)) != 0:
        print("data size not match, size: {0}, batch_size: {1}, timesteps: {2}".format(size, batch_size, timesteps))
        return None, None
   
    X, Y0 = data[:, :-1], data[:, -1]
    
    X = X.reshape((-1, timesteps, X.shape[1]))
    
    Y = np.array([np.array(y) for y in Y0])
    
    Y = Y.reshape((-1, timesteps, Y.shape[1]))
    
    print("X.shape: {0} Y.shape: {1}".format(X.shape, Y.shape))
    
    return X, Y

# %% [markdown]
# ## 数据分析

# %%
data_all = data_load()

# %%
idx_dict = {'上证50': 999987, '沪深300': 300, '中证500': 990905, '中小板指': 399005, '创业板指': 399006}

# %%
# 确认指数代码
for idx_name in idx_dict:
    print("name: {0}".format(idx_name))
    Id = data_all[data_all['name'] == idx_name].index.get_level_values('code').unique()
    print("Id: {0}".format(Id))
# Out:
# name: 中小板指
# Id: Int64Index([399005, 399329], dtype='int64', name='code')
# name: 沪深300
# Id: Int64Index([300, 399300], dtype='int64', name='code')
# name: 上证50
# Id: Int64Index([999987], dtype='int64', name='code')
# name: 创业板指
# Id: Int64Index([399006], dtype='int64', name='code')
# name: 中证500
# Id: Int64Index([990905, 999905], dtype='int64', name='code')

# %%
years = pd.date_range('1/1/2006', periods=11, freq='A')

# %%
def data_stat(data, years, idx_dict):
    idxes_des = pd.DataFrame()
    for name in idx_dict:
        # print(name)
        code = idx_dict[name]
        query_code = 'code=={0}'.format(code)
        # print("query code: {0}".format(query_code))
        data_code = data.query(query_code)
        data_code_c = data_clean(data_code)
        data_code_t = data_transform(data_code_c)
        idx_des = pd.DataFrame()
        for year in years:
            end_date = year
            begin_date  = year.replace(month=1, day=1)
            query_date = 'date>"{0}" & date < "{1}"'.format(begin_date, end_date)
            # print("query date: {0}".format(query_date))
            data_code_year = data_code_t.query(query_date)
            describe = data_code_year.close.describe()
            df_describe = describe.to_frame().reset_index()
            df_describe['date'] = year
            idx_des = pd.concat([idx_des, df_describe])
        idx_des = idx_des.pivot(index='date', columns='index', values='close')    
        idx_des['code'] = code
        idxes_des = pd.concat([idxes_des, idx_des])
    return idxes_des

# %%
data_stat = data_stat(data_all, years, idx_dict)

# %%
data_stat_d = data_stat.drop(['count', 'min', 'max', 'std'],axis=1).dropna()

# %%
t = data_stat_d.reset_index().set_index(['code', 'date'])
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8, 6))
t.loc[999987].plot(ax=axes[0, 0])
t.loc[300].plot(ax=axes[0, 1])
t.loc[990905].plot(ax=axes[1, 0])
t.loc[399005].plot(ax=axes[1, 1])
t.loc[399006].plot(ax=axes[2, 0])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 模型

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.layers import LSTM, Dense, Dropout, BatchNormalization, Activation


model = Sequential()
# input layer
# activation='relu' 
# dropout=0.5
# kernel_initializer="uniform"
model.add(LSTM(units, stateful=True, return_sequences=True, batch_input_shape=(batch_size, timesteps, data_dim), kernel_initializer="uniform"))
# hidden layer
model.add(LSTM(units, return_sequences=True, stateful=True, dropout=0.5, kernel_initializer="uniform"))
model.add(LSTM(units, return_sequences=True, stateful=True, dropout=0.5, kernel_initializer="uniform"))
model.add(LSTM(units, return_sequences=True, stateful=True, dropout=0.5, kernel_initializer="uniform"))

# 回归问题
# # output layer
# # model.add(Dense(no_classes, activation='softmax'))
# model.add(Dense(1, activation='sigmoid')) # or sigmoid?
# # model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# model.compile(optimizer='RMSProp', loss='mse') #mse

# 分类问题
# output layer
model.add(Dense(num_classes, activation='softmax'))
# model.add(Dense(num_classes, kernel_initializer="uniform"))
# model.add(BatchNormalization())
# model.add(Activation('softmax'))

from keras.optimizers import SGD, Adam, RMSprop
model.compile(optimizer=RMSprop(0.0005), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (4, 32, 32)               5248
# _________________________________________________________________
# lstm_2 (LSTM)                (4, 32, 32)               8320
# _________________________________________________________________
# lstm_3 (LSTM)                (4, 32, 32)               8320
# _________________________________________________________________
# lstm_4 (LSTM)                (4, 32, 32)               8320
# _________________________________________________________________
# dense_1 (Dense)              (4, 32, 3)                99
# =================================================================
# Total params: 30,307
# Trainable params: 30,307
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 数据集

# %% [markdown]
# ### 测试集

# %%
def get_data_set(data, codes, date_query, timesteps, batch_size):
    test_set = {}
    for code in codes:
        query_str = 'code=={0} & {1}'.format(code, date_query)
        data_match = get_data(data, timesteps, batch_size, query_str)
        data_cleaned = data_clean(data_match)
        data_transformed = data_transform(data_cleaned)
        print(data_transformed.index[0])
        print(data_transformed.index[-1])
        test_set[code] = data_transformed
    return test_set

# %%
test_codes = ['990905', '999987']
test_date_query = 'date>"20141120"'

# %%
raw_test_set = get_data_set(data_all, test_codes, test_date_query, timesteps, batch_size)
# Out:
# data set: 0:512 of 517
# (990905, Timestamp('2014-11-21 00:00:00'))
# (990905, Timestamp('2016-12-23 00:00:00'))
# data set: 0:512 of 517
# (999987, Timestamp('2014-11-21 00:00:00'))
# (999987, Timestamp('2016-12-23 00:00:00'))

# %%
raw_test_set['999987'].tail(5)
# Out:
#                        open      high       low     close  stick_type  \
# code   date
# 999987 2016-12-19 -0.001130  0.000595 -0.006086 -0.004748          -1
#        2016-12-20  0.000880  0.001628 -0.012441 -0.005107          -1
#        2016-12-21  0.001071  0.010930  0.001015  0.007759           1
#        2016-12-22 -0.001751  0.000356 -0.007218 -0.002320          -1
#        2016-12-23 -0.000781 -0.000139 -0.009124 -0.005918          -1
#
#                     up_line  down_line  close_open            class
# code   date
# 999987 2016-12-19  0.001725   0.001339   -0.003618  [1.0, 0.0, 0.0]
#        2016-12-20  0.000748   0.007334   -0.005986  [0.0, 0.0, 1.0]
#        2016-12-21  0.003171   0.000056    0.006688  [0.0, 1.0, 0.0]
#        2016-12-22  0.002107   0.004899   -0.000569  [1.0, 0.0, 0.0]
#        2016-12-23  0.000642   0.003206   -0.005136  [0.0, 1.0, 0.0]

# %%
test_set = {}
for code in raw_test_set:
    test_set[code] = data_reform(normalize(raw_test_set[code]).values, batch_size, timesteps)
# Out:
# shape: (512, 9)
# X.shape: (16, 32, 8) Y.shape: (16, 32, 3)
# shape: (512, 9)
# X.shape: (16, 32, 8) Y.shape: (16, 32, 3)

# %%
idxes = data_all.index.get_level_values('code').unique()

# %% [markdown]
# ### 训练集

# %%
train_map = {'上证50': 999987, '沪深300': 300, '中证500': 990905, '中小板指': 399005, '创业板指': 399006}

# %%
# train sets
train_codes = []
for key in train_map:
    train_codes.append(train_map[key])
    
train_date_query = 'date<"20150101"'

raw_train_set = get_data_set(data_all, train_codes, train_date_query, timesteps, batch_size)
# Out:
# data set: 0:2048 of 2171
# (399005, Timestamp('2006-01-24 00:00:00'))
# (399005, Timestamp('2014-07-03 00:00:00'))
# data set: 0:2304 of 2360
# (300, Timestamp('2005-04-08 00:00:00'))
# (300, Timestamp('2014-10-14 00:00:00'))
# data set: 0:2560 of 2670
# (999987, Timestamp('2004-01-02 00:00:00'))
# (999987, Timestamp('2014-07-22 00:00:00'))
# data set: 0:1024 of 1113
# (399006, Timestamp('2010-06-01 00:00:00'))
# (399006, Timestamp('2014-08-20 00:00:00'))
# data set: 0:1920 of 1928
# (990905, Timestamp('2007-01-26 00:00:00'))
# (990905, Timestamp('2014-12-19 00:00:00'))

# %%
raw_train_set[300].head()
# Out:
#                      open      high       low     close  stick_type   up_line  \
# code date
# 300  2005-04-08  0.000000  0.000000  0.000000  0.000000          -1  0.000000
#      2005-04-11  0.000433  0.005272 -0.010635 -0.007996          -1  0.004839
#      2005-04-12 -0.001718 -0.001718 -0.017296 -0.016801          -1  0.000000
#      2005-04-13  0.009454  0.028407  0.009454  0.022686           1  0.005721
#      2005-04-14  0.003737  0.005511 -0.015308 -0.013912          -1  0.001774
#
#                  down_line  close_open            class
# code date
# 300  2005-04-08   0.000000    0.000000  [1.0, 0.0, 0.0]
#      2005-04-11   0.002639   -0.008429  [1.0, 0.0, 0.0]
#      2005-04-12   0.000495   -0.015083  [0.0, 0.0, 1.0]
#      2005-04-13   0.000000    0.013232  [1.0, 0.0, 0.0]
#      2005-04-14   0.001396   -0.017649  [1.0, 0.0, 0.0]

# %%
train_set = {}
for code in raw_train_set:
    train_set[code] = data_reform(normalize(raw_train_set[code]).values, batch_size, timesteps)
# Out:
# shape: (1920, 9)
# X.shape: (60, 32, 8) Y.shape: (60, 32, 3)
# shape: (2560, 9)
# X.shape: (80, 32, 8) Y.shape: (80, 32, 3)
# shape: (2304, 9)
# X.shape: (72, 32, 8) Y.shape: (72, 32, 3)
# shape: (2048, 9)
# X.shape: (64, 32, 8) Y.shape: (64, 32, 3)
# shape: (1024, 9)
# X.shape: (32, 32, 8) Y.shape: (32, 32, 3)

# %% [markdown]
# ## 训练

# %%
from influxdb import InfluxDBClient
from influxdb import SeriesHelper
host = '183.136.205.102'
port = 38086
user = 'root'
password = 'root'
dbname = 'chq'

myclient = InfluxDBClient(host, port, user, password, dbname)

# %%
trainid = 1
class MySeriesHelper(SeriesHelper):
    # Meta class stores time series helper configuration.
    class Meta:
        # The client should be an instance of InfluxDBClient.
        client = myclient
        # The series name must be a string. Add dependent fields/tags in curly brackets.
        series_name = 'deeplearning.train' + str(trainid)
        # Defines all the fields in this time series.
        fields = ['loss', 'acc']
        # Defines all the tags for the series.
        tags = ['dtype', 'code', 'epoch']
        # Defines the number of data points to store prior to writing on the wire.
        bulk_size = 5
        # autocommit must be set to True when using bulk_size
        autocommit = True

# %%
epochs =2000
def train(model, train_set, test_set, epochs, batch_size):
# def train():
    for e in range(epochs):
        for code in train_set:
            print("epochs: {0}, code: {1}".format(e, code))
            train_X, train_Y = train_set[code]
            # print(train_X.shape, train_Y.shape, test_X.shape, test_Y.shape)
            # history = model.fit(train_X, train_Y, epochs=100, batch_size=batch_size, validation_data=(test_X, test_Y), verbose=1, shuffle=False)
            history = model.fit(train_X, train_Y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)
            model.reset_states()  
            # result = {'type': 'train', 'code': code, 'train_loss': (e, history.history['loss'][-1]), 'train_acc': (e, history.history['acc'][-1])}
            MySeriesHelper(dtype="train", code=code, epoch = e, loss=history.history['loss'][-1], acc= history.history['acc'][-1])
            # print(result)
        MySeriesHelper.commit()
            # yield result
        for code in test_set:
            test_X1, test_Y1 = test_set[code]
            loss_and_metrics = model.evaluate(test_X1, test_Y1, batch_size=batch_size)
            model.reset_states()
            # result = {'type': 'test', 'code': code, 'test_loss': (e, loss_and_metrics[0]), 'test_acc': (e, loss_and_metrics[1])}
            MySeriesHelper(dtype="test", code=code, epoch = e, loss=loss_and_metrics[0], acc= loss_and_metrics[1])
            # print(result)
        MySeriesHelper.commit()
            # yield result
                # print("==================================")
                # print("loss_and_metrics: {0}".format(loss_and_metrics))
                # print("==================================")

#     def data_gen(t=0):
#         cnt = 0
#         while cnt < 1000:
#             cnt += 1
#             t += 0.1
#             yield t, np.sin(2*np.pi*t) * np.exp(-t/10.)
# ani = animation.FuncAnimation(fig, run, train, repeat=False, init_func=init)
# plt.show()

# %%
train(model, train_set, test_set, epochs, batch_size)
# Out:
# epochs: 0, code: 990905
# epochs: 0, code: 999987
# epochs: 0, code: 300
# epochs: 0, code: 399005
# epochs: 0, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 1, code: 990905
# epochs: 1, code: 999987
# epochs: 1, code: 300
# epochs: 1, code: 399005
# epochs: 1, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 2, code: 990905
# epochs: 2, code: 999987
# epochs: 2, code: 300
# epochs: 2, code: 399005
# epochs: 2, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 3, code: 990905
# epochs: 3, code: 999987
# epochs: 3, code: 300
# epochs: 3, code: 399005
# epochs: 3, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 4, code: 990905
# epochs: 4, code: 999987
# epochs: 4, code: 300
# epochs: 4, code: 399005
# epochs: 4, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 5, code: 990905
# epochs: 5, code: 999987
# epochs: 5, code: 300
# epochs: 5, code: 399005
# epochs: 5, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 6, code: 990905
# epochs: 6, code: 999987
# epochs: 6, code: 300
# epochs: 6, code: 399005
# epochs: 6, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 7, code: 990905
# epochs: 7, code: 999987
# epochs: 7, code: 300
# epochs: 7, code: 399005
# epochs: 7, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 8, code: 990905
# epochs: 8, code: 999987
# epochs: 8, code: 300
# epochs: 8, code: 399005
# epochs: 8, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 9, code: 990905
# epochs: 9, code: 999987
# epochs: 9, code: 300
# epochs: 9, code: 399005
# epochs: 9, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 10, code: 990905
# epochs: 10, code: 999987
# epochs: 10, code: 300
# epochs: 10, code: 399005
# epochs: 10, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 11, code: 990905
# epochs: 11, code: 999987
# epochs: 11, code: 300
# epochs: 11, code: 399005
# epochs: 11, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 12, code: 990905
# epochs: 12, code: 999987
# epochs: 12, code: 300
# epochs: 12, code: 399005
# epochs: 12, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 13, code: 990905
# epochs: 13, code: 999987
# epochs: 13, code: 300
# epochs: 13, code: 399005
# epochs: 13, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 14, code: 990905
# epochs: 14, code: 999987
# epochs: 14, code: 300
# epochs: 14, code: 399005
# epochs: 14, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 15, code: 990905
# epochs: 15, code: 999987
# epochs: 15, code: 300
# epochs: 15, code: 399005
# epochs: 15, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 16, code: 990905
# epochs: 16, code: 999987
# epochs: 16, code: 300
# epochs: 16, code: 399005
# epochs: 16, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 17, code: 990905
# epochs: 17, code: 999987
# epochs: 17, code: 300
# epochs: 17, code: 399005
# epochs: 17, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 18, code: 990905
# epochs: 18, code: 999987
# epochs: 18, code: 300
# epochs: 18, code: 399005
# epochs: 18, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 19, code: 990905
# epochs: 19, code: 999987
# epochs: 19, code: 300
# epochs: 19, code: 399005
# epochs: 19, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 20, code: 990905
# epochs: 20, code: 999987
# epochs: 20, code: 300
# epochs: 20, code: 399005
# epochs: 20, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 21, code: 990905
# epochs: 21, code: 999987
# epochs: 21, code: 300
# epochs: 21, code: 399005
# epochs: 21, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 22, code: 990905
# epochs: 22, code: 999987
# epochs: 22, code: 300
# epochs: 22, code: 399005
# epochs: 22, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 23, code: 990905
# epochs: 23, code: 999987
# epochs: 23, code: 300
# epochs: 23, code: 399005
# epochs: 23, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 24, code: 990905
# epochs: 24, code: 999987
# epochs: 24, code: 300
# epochs: 24, code: 399005
# epochs: 24, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 25, code: 990905
# epochs: 25, code: 999987
# epochs: 25, code: 300
# epochs: 25, code: 399005
# epochs: 25, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 26, code: 990905
# epochs: 26, code: 999987
# epochs: 26, code: 300
# epochs: 26, code: 399005
# epochs: 26, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 27, code: 990905
# epochs: 27, code: 999987
# epochs: 27, code: 300
# epochs: 27, code: 399005
# epochs: 27, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 28, code: 990905
# epochs: 28, code: 999987
# epochs: 28, code: 300
# epochs: 28, code: 399005
# epochs: 28, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 29, code: 990905
# epochs: 29, code: 999987
# epochs: 29, code: 300
# epochs: 29, code: 399005
# epochs: 29, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 30, code: 990905
# epochs: 30, code: 999987
# epochs: 30, code: 300
# epochs: 30, code: 399005
# epochs: 30, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 31, code: 990905
# epochs: 31, code: 999987
# epochs: 31, code: 300
# epochs: 31, code: 399005
# epochs: 31, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 32, code: 990905
# epochs: 32, code: 999987
# epochs: 32, code: 300
# epochs: 32, code: 399005
# epochs: 32, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 33, code: 990905
# epochs: 33, code: 999987
# epochs: 33, code: 300
# epochs: 33, code: 399005
# epochs: 33, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 34, code: 990905
# epochs: 34, code: 999987
# epochs: 34, code: 300
# epochs: 34, code: 399005
# epochs: 34, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 35, code: 990905
# epochs: 35, code: 999987
# epochs: 35, code: 300
# epochs: 35, code: 399005
# epochs: 35, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 36, code: 990905
# epochs: 36, code: 999987
# epochs: 36, code: 300
# epochs: 36, code: 399005
# epochs: 36, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 37, code: 990905
# epochs: 37, code: 999987
# epochs: 37, code: 300
# epochs: 37, code: 399005
# epochs: 37, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 38, code: 990905
# epochs: 38, code: 999987
# epochs: 38, code: 300
# epochs: 38, code: 399005
# epochs: 38, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 39, code: 990905
# epochs: 39, code: 999987
# epochs: 39, code: 300
# epochs: 39, code: 399005
# epochs: 39, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 40, code: 990905
# epochs: 40, code: 999987
# epochs: 40, code: 300
# epochs: 40, code: 399005
# epochs: 40, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 41, code: 990905
# epochs: 41, code: 999987
# epochs: 41, code: 300
# epochs: 41, code: 399005
# epochs: 41, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 42, code: 990905
# epochs: 42, code: 999987
# epochs: 42, code: 300
# epochs: 42, code: 399005
# epochs: 42, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 43, code: 990905
# epochs: 43, code: 999987
# epochs: 43, code: 300
# epochs: 43, code: 399005
# epochs: 43, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 44, code: 990905
# epochs: 44, code: 999987
# epochs: 44, code: 300
# epochs: 44, code: 399005
# epochs: 44, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 45, code: 990905
# epochs: 45, code: 999987
# epochs: 45, code: 300
# epochs: 45, code: 399005
# epochs: 45, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 46, code: 990905
# epochs: 46, code: 999987
# epochs: 46, code: 300
# epochs: 46, code: 399005
# epochs: 46, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 47, code: 990905
# epochs: 47, code: 999987
# epochs: 47, code: 300
# epochs: 47, code: 399005
# epochs: 47, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 48, code: 990905
# epochs: 48, code: 999987
# epochs: 48, code: 300
# epochs: 48, code: 399005
# epochs: 48, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 49, code: 990905
# epochs: 49, code: 999987
# epochs: 49, code: 300
# epochs: 49, code: 399005
# epochs: 49, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 50, code: 990905
# epochs: 50, code: 999987
# epochs: 50, code: 300
# epochs: 50, code: 399005
# epochs: 50, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 51, code: 990905
# epochs: 51, code: 999987
# epochs: 51, code: 300
# epochs: 51, code: 399005
# epochs: 51, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 52, code: 990905
# epochs: 52, code: 999987
# epochs: 52, code: 300
# epochs: 52, code: 399005
# epochs: 52, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 53, code: 990905
# epochs: 53, code: 999987
# epochs: 53, code: 300
# epochs: 53, code: 399005
# epochs: 53, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 54, code: 990905
# epochs: 54, code: 999987
# epochs: 54, code: 300
# epochs: 54, code: 399005
# epochs: 54, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 55, code: 990905
# epochs: 55, code: 999987
# epochs: 55, code: 300
# epochs: 55, code: 399005
# epochs: 55, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 56, code: 990905
# epochs: 56, code: 999987
# epochs: 56, code: 300
# epochs: 56, code: 399005
# epochs: 56, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 57, code: 990905
# epochs: 57, code: 999987
# epochs: 57, code: 300
# epochs: 57, code: 399005
# epochs: 57, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 58, code: 990905
# epochs: 58, code: 999987
# epochs: 58, code: 300
# epochs: 58, code: 399005
# epochs: 58, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 59, code: 990905
# epochs: 59, code: 999987
# epochs: 59, code: 300
# epochs: 59, code: 399005
# epochs: 59, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 60, code: 990905
# epochs: 60, code: 999987
# epochs: 60, code: 300
# epochs: 60, code: 399005
# epochs: 60, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs:
code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 192, code: 990905
# epochs: 192, code: 999987
# epochs: 192, code: 300
# epochs: 192, code: 399005
# epochs: 192, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 193, code: 990905
# epochs: 193, code: 999987
# epochs: 193, code: 300
# epochs: 193, code: 399005
# epochs: 193, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 194, code: 990905
# epochs: 194, code: 999987
# epochs: 194, code: 300
# epochs: 194, code: 399005
# epochs: 194, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 195, code: 990905
# epochs: 195, code: 999987
# epochs: 195, code: 300
# epochs: 195, code: 399005
# epochs: 195, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 196, code: 990905
# epochs: 196, code: 999987
# epochs: 196, code: 300
# epochs: 196, code: 399005
# epochs: 196, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 197, code: 990905
# epochs: 197, code: 999987
# epochs: 197, code: 300
# epochs: 197, code: 399005
# epochs: 197, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 198, code: 990905
# epochs: 198, code: 999987
# epochs: 198, code: 300
# epochs: 198, code: 399005
# epochs: 198, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 199, code: 990905
# epochs: 199, code: 999987
# epochs: 199, code: 300
# epochs: 199, code: 399005
# epochs: 199, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 200, code: 990905
# epochs: 200, code: 999987
# epochs: 200, code: 300
# epochs: 200, code: 399005
# epochs: 200, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 201, code: 990905
# epochs: 201, code: 999987
# epochs: 201, code: 300
# epochs: 201, code: 399005
# epochs: 201, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 202, code: 990905
# epochs: 202, code: 999987
# epochs: 202, code: 300
# epochs: 202, code: 399005
# epochs: 202, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 203, code: 990905
# epochs: 203, code: 999987
# epochs: 203, code: 300
# epochs: 203, code: 399005
# epochs: 203, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 204, code: 990905
# epochs: 204, code: 999987
# epochs: 204, code: 300
# epochs: 204, code: 399005
# epochs: 204, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 205, code: 990905
# epochs: 205, code: 999987
# epochs: 205, code: 300
# epochs: 205, code: 399005
# epochs: 205, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 206, code: 990905
# epochs: 206, code: 999987
# epochs: 206, code: 300
# epochs: 206, code: 399005
# epochs: 206, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 207, code: 990905
# epochs: 207, code: 999987
# epochs: 207, code: 300
# epochs: 207, code: 399005
# epochs: 207, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 208, code: 990905
# epochs: 208, code: 999987
# epochs: 208, code: 300
# epochs: 208, code: 399005
# epochs: 208, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 209, code: 990905
# epochs: 209, code: 999987
# epochs: 209, code: 300
# epochs: 209, code: 399005
# epochs: 209, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 210, code: 990905
# epochs: 210, code: 999987
# epochs: 210, code: 300
# epochs: 210, code: 399005
# epochs: 210, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 211, code: 990905
# epochs: 211, code: 999987
# epochs: 211, code: 300
# epochs: 211, code: 399005
# epochs: 211, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 212, code: 990905
# epochs: 212, code: 999987
# epochs: 212, code: 300
# epochs: 212, code: 399005
# epochs: 212, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 213, code: 990905
# epochs: 213, code: 999987
# epochs: 213, code: 300
# epochs: 213, code: 399005
# epochs: 213, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 214, code: 990905
# epochs: 214, code: 999987
# epochs: 214, code: 300
# epochs: 214, code: 399005
# epochs: 214, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 215, code: 990905
# epochs: 215, code: 999987
# epochs: 215, code: 300
# epochs: 215, code: 399005
# epochs: 215, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 216, code: 990905
# epochs: 216, code: 999987
# epochs: 216, code: 300
# epochs: 216, code: 399005
# epochs: 216, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 217, code: 990905
# epochs: 217, code: 999987
# epochs: 217, code: 300
# epochs: 217, code: 399005
# epochs: 217, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs:
code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 245, code: 990905
# epochs: 245, code: 999987
# epochs: 245, code: 300
# epochs: 245, code: 399005
# epochs: 245, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 246, code: 990905
# epochs: 246, code: 999987
# epochs: 246, code: 300
# epochs: 246, code: 399005
# epochs: 246, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 247, code: 990905
# epochs: 247, code: 999987
# epochs: 247, code: 300
# epochs: 247, code: 399005
# epochs: 247, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 248, code: 990905
# epochs: 248, code: 999987
# epochs: 248, code: 300
# epochs: 248, code: 399005
# epochs: 248, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 249, code: 990905
# epochs: 249, code: 999987
# epochs: 249, code: 300
# epochs: 249, code: 399005
# epochs: 249, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 250, code: 990905
# epochs: 250, code: 999987
# epochs: 250, code: 300
# epochs: 250, code: 399005
# epochs: 250, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 251, code: 990905
# epochs: 251, code: 999987
# epochs: 251, code: 300
# epochs: 251, code: 399005
# epochs: 251, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 252, code: 990905
# epochs: 252, code: 999987
# epochs: 252, code: 300
# epochs: 252, code: 399005
# epochs: 252, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 253, code: 990905
# epochs: 253, code: 999987
# epochs: 253, code: 300
# epochs: 253, code: 399005
# epochs: 253, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 254, code: 990905
# epochs: 254, code: 999987
# epochs: 254, code: 300
# epochs: 254, code: 399005
# epochs: 254, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 255, code: 990905
# epochs: 255, code: 999987
# epochs: 255, code: 300
# epochs: 255, code: 399005
# epochs: 255, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 256, code: 990905
# epochs: 256, code: 999987
# epochs: 256, code: 300
# epochs: 256, code: 399005
# epochs: 256, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 257, code: 990905
# epochs: 257, code: 999987
# epochs: 257, code: 300
# epochs: 257, code: 399005
# epochs: 257, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 258, code: 990905
# epochs: 258, code: 999987
# epochs: 258, code: 300
# epochs: 258, code: 399005
# epochs: 258, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 259, code: 990905
# epochs: 259, code: 999987
# epochs: 259, code: 300
# epochs: 259, code: 399005
# epochs: 259, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 260, code: 990905
# epochs: 260, code: 999987
# epochs: 260, code: 300
# epochs: 260, code: 399005
# epochs: 260, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 261, code: 990905
# epochs: 261, code: 999987
# epochs: 261, code: 300
# epochs: 261, code: 399005
# epochs: 261, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 262, code: 990905
# epochs: 262, code: 999987
# epochs: 262, code: 300
# epochs: 262, code: 399005
# epochs: 262, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 263, code: 990905
# epochs: 263, code: 999987
# epochs: 263, code: 300
# epochs: 263, code: 399005
# epochs: 263, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 264, code: 990905
# epochs: 264, code: 999987
# epochs: 264, code: 300
# epochs: 264, code: 399005
# epochs: 264, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 265, code: 990905
# epochs: 265, code: 999987
# epochs: 265, code: 300
# epochs: 265, code: 399005
# epochs: 265, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 266, code: 990905
# epochs: 266, code: 999987
# epochs: 266, code: 300
# epochs: 266, code: 399005
# epochs: 266, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 267, code: 990905
# epochs: 267, code: 999987
# epochs: 267, code: 300
# epochs: 267, code: 399005
# epochs: 267, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 268, code: 990905
# epochs: 268, code: 999987
# epochs: 268, code: 300
# epochs: 268, code: 399005
# epochs: 268, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 269, code: 990905
# epochs: 269, code: 999987
# epochs: 269, code: 300
# epochs: 269, code: 399005
# epochs: 269, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 270, code: 990905
# epochs: 270, code: 999987
# epochs: 270, code: 300
# epochs: 270, code: 399005
# epochs: 270, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 271, code: 990905
# epochs: 271, code: 999987
# epochs: 271, code: 300
# epochs: 271, code: 399005
# epochs: 271, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 272, code: 990905
# epochs: 272, code: 999987
# epochs: 272, code: 300
# epochs: 272, code: 399005
# epochs: 272, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 273, code: 990905
# epochs: 273, code: 999987
# epochs: 273, code: 300
# epochs: 273, code: 399005
# epochs: 273, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 274, code: 990905
# epochs: 274, code: 999987
# epochs: 274, code: 300
# epochs: 274, code: 399005
# epochs: 274, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 275, code: 990905
# epochs: 275, code: 999987
# epochs: 275, code: 300
# epochs: 275, code: 399005
# epochs: 275, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 276, code: 990905
# epochs: 276, code: 999987
# epochs: 276, code: 300
# epochs: 276, code: 399005
# epochs: 276, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 277, code: 990905
# epochs: 277, code: 999987
# epochs: 277, code: 300
# ...
# epochs: 849, code: 399005
# epochs: 849, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 850, code: 990905
# epochs: 850, code: 999987
# epochs: 850, code: 300
# epochs: 850, code: 399005
# epochs: 850, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 851, code: 990905
# epochs: 851, code: 999987
# epochs: 851, code: 300
# epochs: 851, code: 399005
# epochs: 851, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 852, code: 990905
# epochs: 852, code: 999987
# epochs: 852, code: 300
# epochs: 852, code: 399005
# epochs: 852, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 853, code: 990905
# epochs: 853, code: 999987
# epochs: 853, code: 300
# epochs: 853, code: 399005
# epochs: 853, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 854, code: 990905
# epochs: 854, code: 999987
# epochs: 854, code: 300
# epochs: 854, code: 399005
# epochs: 854, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 855, code: 990905
# epochs: 855, code: 999987
# epochs: 855, code: 300
# epochs: 855, code: 399005
# epochs: 855, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 856, code: 990905
# epochs: 856, code: 999987
# epochs: 856, code: 300
# epochs: 856, code: 399005
# epochs: 856, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 857, code: 990905
# epochs: 857, code: 999987
# epochs: 857, code: 300
# epochs: 857, code: 399005
# epochs: 857, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 858, code: 990905
# epochs: 858, code: 999987
# epochs: 858, code: 300
# epochs: 858, code: 399005
# epochs: 858, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 859, code: 990905
# epochs: 859, code: 999987
# epochs: 859, code: 300
# epochs: 859, code: 399005
# epochs: 859, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 860, code: 990905
# epochs: 860, code: 999987
# epochs: 860, code: 300
# epochs: 860, code: 399005
# epochs: 860, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 861, code: 990905
# epochs: 861, code: 999987
# epochs: 861, code: 300
# epochs: 861, code: 399005
# epochs: 861, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 862, code: 990905
# epochs: 862, code: 999987
# epochs: 862, code: 300
# epochs: 862, code: 399005
# epochs: 862, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 863, code: 990905
# epochs: 863, code: 999987
# epochs: 863, code: 300
# epochs: 863, code: 399005
# epochs: 863, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 864, code: 990905
# epochs: 864, code: 999987
# epochs: 864, code: 300
# epochs: 864, code: 399005
# epochs: 864, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 865, code: 990905
# epochs: 865, code: 999987
# epochs: 865, code: 300
# epochs: 865, code: 399005
# epochs: 865, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 866, code: 990905
# epochs: 866, code: 999987
# epochs: 866, code: 300
# epochs: 866, code: 399005
# epochs: 866, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 867, code: 990905
# epochs: 867, code: 999987
# epochs: 867, code: 300
# epochs: 867, code: 399005
# epochs: 867, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs:
code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 895, code: 990905
# epochs: 895, code: 999987
# epochs: 895, code: 300
# epochs: 895, code: 399005
# epochs: 895, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 896, code: 990905
# epochs: 896, code: 999987
# epochs: 896, code: 300
# epochs: 896, code: 399005
# epochs: 896, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 897, code: 990905
# epochs: 897, code: 999987
# epochs: 897, code: 300
# epochs: 897, code: 399005
# epochs: 897, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 898, code: 990905
# epochs: 898, code: 999987
# epochs: 898, code: 300
# epochs: 898, code: 399005
# epochs: 898, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 899, code: 990905
# epochs: 899, code: 999987
# epochs: 899, code: 300
# epochs: 899, code: 399005
# epochs: 899, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 900, code: 990905
# epochs: 900, code: 999987
# epochs: 900, code: 300
# epochs: 900, code: 399005
# epochs: 900, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 901, code: 990905
# epochs: 901, code: 999987
# epochs: 901, code: 300
# epochs: 901, code: 399005
# epochs: 901, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 902, code: 990905
# epochs: 902, code: 999987
# epochs: 902, code: 300
# epochs: 902, code: 399005
# epochs: 902, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 903, code: 990905
# epochs: 903, code: 999987
# epochs: 903, code: 300
# epochs: 903, code: 399005
# epochs: 903, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 904, code: 990905
# epochs: 904, code: 999987
# epochs: 904, code: 300
# epochs: 904, code: 399005
# epochs: 904, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 905, code: 990905
# epochs: 905, code: 999987
# epochs: 905, code: 300
# epochs: 905, code: 399005
# epochs: 905, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 906, code: 990905
# epochs: 906, code: 999987
# epochs: 906, code: 300
# epochs: 906, code: 399005
# epochs: 906, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 907, code: 990905
# epochs: 907, code: 999987
# epochs: 907, code: 300
# epochs: 907, code: 399005
# epochs: 907, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 908, code: 990905
# epochs: 908, code: 999987
# epochs: 908, code: 300
# epochs: 908, code: 399005
# epochs: 908, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 909, code: 990905
# epochs: 909, code: 999987
# epochs: 909, code: 300
# epochs: 909, code: 399005
# epochs: 909, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 910, code: 990905
# epochs: 910, code: 999987
# epochs: 910, code: 300
# epochs: 910, code: 399005
# epochs: 910, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 911, code: 990905
# epochs: 911, code: 999987
# epochs: 911, code: 300
# epochs: 911, code: 399005
# epochs: 911, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 912, code: 990905
# epochs: 912, code: 999987
# epochs: 912, code: 300
# epochs: 912, code: 399005
# epochs: 912, code: 399006
#  4/16 [======>.......................] - ETA: 0sepochs: 913, code: 990905
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-da92401db527> in <module>()
# ----> 1 train(model, train_set, test_set, epochs, batch_size)
#
# <ipython-input-32-5e4314a797a7> in train(model, train_set, test_set, epochs, batch_size)
#       8             # print(train_X.shape, train_Y.shape, test_X.shape, test_Y.shape)
#       9             # history = model.fit(train_X, train_Y, epochs=100, batch_size=batch_size, validation_data=(test_X, test_Y), verbose=1, shuffle=False)
# ---> 10             history = model.fit(train_X, train_Y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)
#      11             model.reset_states()
#      12             # result = {'type': 'train', 'code': code, 'train_loss': (e, history.history['loss'][-1]), 'train_acc': (e, history.history['acc'][-1])}
#
# ~/.pyenv/versions/3.5.3/lib/python3.5/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     861                               class_weight=class_weight,
#     862                               sample_weight=sample_weight,
# --> 863                               initial_epoch=initial_epoch)
#     864
#     865     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# ~/.pyenv/versions/3.5.3/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1428                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1429                               callback_metrics=callback_metrics,
# -> 1430                               initial_epoch=initial_epoch)
#    1431
#    1432     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# ~/.pyenv/versions/3.5.3/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#    1077                 batch_logs['size'] = len(batch_ids)
#    1078                 callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1079                 outs = f(ins_batch)
#    1080                 if not isinstance(outs, list):
#    1081                     outs = [outs]
#
# ~/.pyenv/versions/3.5.3/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2266         updated = session.run(self.outputs + [self.updates_op],
#    2267                               feed_dict=feed_dict,
# -> 2268                               **self.session_kwargs)
#    2269         return updated[:len(self.outputs)]
#    2270
#
# ~/.pyenv/versions/3.5.3/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.pyenv/versions/3.5.3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# ~/.pyenv/versions/3.5.3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/.pyenv/versions/3.5.3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# ~/.pyenv/versions/3.5.3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# def data_gen(t=0):
#     cnt = 0
#     while cnt < 1000:
#         cnt += 1
#         t += 0.1
#         yield t, np.sin(2*np.pi*t) * np.exp(-t/10.)

# %%
# ani = animation.FuncAnimation(fig, run, data_gen, repeat=False, init_func=init)
# plt.show()

# %%
# train(model, train_set, test_set, 100, batch_size)

# %%
plt.show()

# %%
train()

# %%
# history = model.fit(train_X, train_Y, epochs=100, batch_size=batch_size, validation_data=(test_X, test_Y), verbose=1, shuffle=False)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plt.plot(history.history['acc'], label='train')
plt.plot(history.history['val_acc'], label='test')
plt.legend()
plt.show()

# %%
predict_Y=model.predict(x=test_X1,batch_size=batch_size)

# %%
predict_Y.shape

# %%
predict_value = np.argmax(predict_Y,axis=2)

# %%
predict_value.shape

# %%
test_set = idx300n.iloc[1800:2400, :].copy()

# %%
test_t2.head()

# %%
def class_argmax(x):
    return np.argmax(x)

# %%
test_set = test_t1

# %%
test_set['class']= test_set['class'].map(class_argmax)

# %%
test_set.head()

# %%
cmp_predict = pd.DataFrame()
cmp_predict['class'] = test_set['class']

# %%
cmp_predict['predict_class'] = predict_value.reshape((-1, ))

# %%
cmp_predict['close'] = test_t2.loc[cmp_predict.index, 'close']

# %%
cmp_predict['diff'] = cmp_predict['predict_class'] - cmp_predict['class']

# %%
cmp_predict.head()

# %%
cmp_predict=cmp_predict.reset_index()

# %%
cmp_predict = cmp_predict.reset_index()

# %%
cmp_predict.head()

# %%
def color(x):
    c = 'm'
    if x < 0:
        c = 'g'
    elif x > 0:
        c = 'r'
    else:
        c = 'b'
    return c
cmp_predict['color'] = cmp_predict['diff'].map(color)

# %%
cmp_predict.plot(kind='scatter', x='index', y='close', s=60, c=cmp_predict.color, figsize=(21, 7))

# %%
test_t2['close'].head(600).plot.hist( bins=30, figsize=(21, 7))

# %%
cmp_predict.tail()

# %%
cmp_predict['predict_class'].plot.hist()

# %%
cmp_predict['class'].plot.hist()

# %%
cmp_predict['next_close'] = cmp_predict['close'].shift(-1)

# %%
cmp_predict['profit'] = cmp_predict['next_close'] - cmp_predict['close']

# %%
cmp_predict.head()

# %%
def predict_profit(x):
    profit = 0
    if x['predict_class'] == 2:
        profit = x['profit']
    elif x['predict_class'] == 0:
        profit = -x['profit']
    else:
        profit = 0
    return profit
cmp_predict['predict_profit'] = cmp_predict.apply(predict_profit, axis=1)

# %%
cmp_predict['predict_profit'].cumsum().plot(figsize=(21, 7))

# %%
cmp_predict.head(400).tail()

# %%
cmp_predict.head()

# %%
cmp_predict[cmp_predict['predict_class']==2]['predict_profit'].cumsum().plot(figsize=(21, 7))

# %%
cmp_predict[cmp_predict['predict_class']==0]['predict_profit'].cumsum().plot(figsize=(21, 7))

# %% [markdown]
# ## 性能评估

# %% [markdown]
# ### 类预测比较

# %% [markdown]
# ### 类分布

# %%
# column: true_class predict_class
def class_compare(df):
    return pd.crosstab(df.true_class, df.predict_class, margins=True)

# %% [markdown]
# ### 利润

# %%
# column: close signal
def portfolio_return_ration(df, direction="both"):
    def profit(x):
        # 归一化
        x[x['signal'] < -1]['signal'] = -1
        x[x['signal'] > 1]['signal'] = 1

        if direction == "long":
            x[x['signal'] < 0]['signal'] = 0
        elif direction == "short":
            x[x['signal'] > 0]['signal'] = 0
            
        x['profit'] = x['diff'] * x['signal']
        return x

    df_tmp = pd.DataFrame()
    pre_close = df['close'].shift(1)
    df_tmp['diff'] =  df['close'] - pre_close
    df_tmp['signal'] = df['signal']
    
    df_tmp['profit'] = df.apply(profit, axis=1)
    return (df_tmp['profit']+1).cumprod()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 20, 100)
y = np.sin(x)
z = x + 20 * y

scaled_z = (x - x.min())
colors = plt.cm.coolwarm(x)

plt.scatter(x, y, marker='+', edgecolors=colors, s=150, linewidths=4)
plt.show()
