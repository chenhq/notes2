# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as snb
snb.set()
import matplotlib.font_manager as fm
myfont = fm.FontProperties(fname='idx/msyh.ttf')

# %%
idx_return_df = pd.read_csv("idx_return_df.csv")

# %%
idx_return_df = idx_return_df.drop("Unnamed: 0", axis=1).set_index('tradeDate')

# %%
idx_return_df.head()
# Out:
#                 深证成指     沪深300     中证500      上证50      中小板指      创业板指  \
# tradeDate
# 2014-01-02  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2014-01-03  0.989394  0.986563  0.991797  0.983965  1.001831  1.014881
# 2014-01-06  0.963530  0.964108  0.964401  0.969144  0.978531  0.992742
# 2014-01-07  0.962033  0.963833  0.970317  0.967686  0.985993  1.014458
# 2014-01-08  0.961520  0.965516  0.971498  0.970683  0.992195  1.054028
#
#                 上证综指
# tradeDate
# 2014-01-02  1.000000
# 2014-01-03  0.987555
# 2014-01-06  0.969812
# 2014-01-07  0.970574
# 2014-01-08  0.969163

# %%
def polyfit(y, n, deg=2):
    x = np.linspace(0, 1, n)
    reg = np.polyfit(x, y, deg)
    if deg == 1:
        return reg[0]
    elif deg == 2:
        return reg[0] * 2 + reg[1]

# %%
def distance_to_plant(x):
    return (x[-1] - x[0]) / x[0]

# %%
def fit2(df, n1, n2, n3, n4):
    r0 = idx_return_df.rolling(30).mean()
    r1 = r0.rolling(n1, min_periods=n1).apply(myfit,args=(n1,))
    r2 = r1.rolling(n2).mean()
#     r3 = r2.rolling(n3, min_periods=n3).apply(myfit,args=(n3,))
#     r4 = r3.rolling(n4, min_periods=n4).mean()
    return r2

# %%
def distance(df, n_average, n_days_ago):
    ma = df.rolling(n_average).mean()
#     ma = ma.dropna()
#     n = n_days_ago
#     d = ma.rolling(n, min_periods=n).apply(distance_to_plant)
    return ma

# %%
def velocity(distance, n_point):
    n = n_point
    v = distance.rolling(n, min_periods=n).apply(polyfit, args=(n,))
    return v

# %%
begin_date = "2017-01-01"
end_date = "2018-01-01"
idx = "沪深300"

# %%
ax = idx_return_df.loc[begin_date:end_date, idx].plot(figsize=(21, 7))
legend = ax.legend()
for text in legend.texts:
    text.set_font_properties(myfont)

# %%
# ax = v.loc[begin_date:end_date, idx].plot(figsize=(21, 7))
# a.loc[begin_date:end_date, idx].plot(figsize=(21, 7))
# legend = ax.legend()
# for text in legend.texts:
#     text.set_font_properties(myfont)

# %%
d = distance(idx_return_df, 30, 50)
ax = d.loc[begin_date:end_date, idx].plot(figsize=(21, 7))
# v.loc[begin_date:end_date, idx].rolling(3).mean().plot(figsize=(21, 7))
# a.loc[begin_date:end_date, idx].rolling(3).mean().plot(figsize=(21, 7))
legend = ax.legend()
for text in legend.texts:
    text.set_font_properties(myfont)

# %%
v = velocity(d, 3)
ax = v.loc[begin_date:end_date, idx].plot(figsize=(21, 7))
a.loc[begin_date:end_date, idx].plot(figsize=(21, 7))
legend = ax.legend()
for text in legend.texts:
    text.set_font_properties(myfont)

# %%
a = velocity(v, 10)
ax = a.loc[begin_date:end_date, idx].plot(figsize=(21, 7))
legend = ax.legend()
for text in legend.texts:
    text.set_font_properties(myfont)

# %%
up_cond = (v[idx] > 0) & (a[idx]>0)

# %%
up = idx_return_df[up_cond.index.values[0]:][up_cond==True][idx]

# %%
down_cond = (v[idx] < 0) & (a[idx]<0)

# %%
down = idx_return_df[down_cond.index.values[0]:][down_cond==True][idx]

# %%
up.head()
# Out:
# tradeDate
# 2014-03-07    0.933841
# 2014-04-08    0.963540
# 2014-04-09    0.964100
# 2014-04-10    0.979233
# 2014-04-11    0.977902
# Name: 沪深300, dtype: float64

# %%
down.head()
# Out:
# tradeDate
# 2014-03-10    0.903449
# 2014-03-11    0.908130
# 2014-03-12    0.910486
# 2014-03-13    0.921769
# 2014-03-14    0.914237
# Name: 沪深300, dtype: float64

# %%
zh_return = idx_return_df[idx] - idx_return_df[idx].shift(1)
zh_return_signal = pd.concat([zh_return, up, down], axis=1)
zh_return_signal.columns = ['idx', 'long', 'short']
zh_return_signal['long'] = zh_return_signal['long'].shift(1)
zh_return_signal['short'] = zh_return_signal['short'].shift(1)
zh_return_signal.tail()
zh_return_signal = zh_return_signal.fillna(0)
def cal_profit(x):
    if x['long'] > 0:
        profit = x['idx']
    elif x['short'] > 0:
        profit = -x['idx']
    else:
        profit = 0
    return profit

zh_return_signal['profit'] = zh_return_signal.apply(cal_profit, axis=1)
begin_date = "2017-01-01"
end_date = "2018-01-01"
(zh_return_signal[zh_return_signal['long'] > 0]['profit'] + 1)[begin_date:end_date].cumprod().plot(figsize=(21, 7))

# %%
def fixed_stop_loss(df, min_return, stop_loss, withdraw, withdraw_percent, column='close'):
    init = df.iloc[0][column]
    max_return = -1
    for idx, row in df.iterrows():
        return_ = row[column] - init
        #print(return_)
        
        if return_ >= max_return:
            # 盈利创新高，继续持仓
            max_return = return_
        else:
            # 盈利下降
            if return_ > min_return:
                # 盈利大于最小盈利
                if return_ * (1 + withdraw_percent) < max_return and (max_return - return_) > withdraw:
                    # 回撤大于固定回撤和回撤百分比
                    break
            else:
                if return_ < init * (- stop_loss):
                    # 止损
                    break
                
    return idx, return_

# %%
def fixed_stop_loss(market, open_signal, min_return, stop_loss, withdraw, withdraw_percent):
    df = pd.concat([market, open_signal], axis=1)
    df.columns = ['price', 'signal']
    df['new_signal'] = 0
    open_status = False
    for idx, row in df.iterrows():
        if open_status:
            df['new_signal'] = 1
            
            return_ = row['price'] - init
            #print(return_)

            if return_ >= max_return:
                # 盈利创新高，继续持仓
                max_return = return_
            else:
                # 盈利下降
                if return_ > min_return:
                    # 盈利大于最小盈利
                    if return_ * (1 + withdraw_percent) < max_return and (max_return - return_) > withdraw:
                        # 回撤大于固定回撤和回撤百分比, 止盈
                        open_status = False
                else:
                    if return_ < init * (- stop_loss):
                        # 止损
                        open_status = False
        else:
            if df['signal'] == 1:
                open_status = True
                init = df.loc[idx]['price']
                max_return = 0
                df['new_signal'] = 1
            else:
                df['new_signal'] = 0

    
    return df['new_signal']

# %%
idx_return_df.head()
# Out:
#                 深证成指     沪深300     中证500      上证50      中小板指      创业板指  \
# tradeDate
# 2014-01-02  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2014-01-03  0.989394  0.986563  0.991797  0.983965  1.001831  1.014881
# 2014-01-06  0.963530  0.964108  0.964401  0.969144  0.978531  0.992742
# 2014-01-07  0.962033  0.963833  0.970317  0.967686  0.985993  1.014458
# 2014-01-08  0.961520  0.965516  0.971498  0.970683  0.992195  1.054028
#
#                 上证综指
# tradeDate
# 2014-01-02  1.000000
# 2014-01-03  0.987555
# 2014-01-06  0.969812
# 2014-01-07  0.970574
# 2014-01-08  0.969163

# %%
fixed_stop_loss(idx_return_df["2017-01-01":], 0.01, 0.01, 0.01, 0.2, column=idx)
# Out:
# ('2017-02-27', 0.044787638129999863)

# %%
up.head()
# Out:
# tradeDate
# 2014-03-07    0.933841
# 2014-04-08    0.963540
# 2014-04-09    0.964100
# 2014-04-10    0.979233
# 2014-04-11    0.977902
# Name: 沪深300, dtype: float64

# %%
def cal_return(df_return, signal, ): 
    open_signal.rolling(open_threshold['window']).sum() > open_threshold['threshold']
    fixed_stop_loss(idx_return_df[idx:], 0.01, 0.01, 0.01, 0.2, column=idx)

# %%
idx_return_close = idx_return_df[idx]

# %%
idx_return_close.head()
# Out:
# tradeDate
# 2014-01-02    1.000000
# 2014-01-03    0.986563
# 2014-01-06    0.964108
# 2014-01-07    0.963833
# 2014-01-08    0.965516
# Name: 沪深300, dtype: float64

# %%
idx_return_close.name = 'close'

# %%
up.name = 'signal_weight'

# %%
market_signal = pd.concat([idx_return_close, up], axis=1)

# %%
market_signal['signal_weight'] = market_signal['signal_weight'].shift(1)

# %%
market_signal.loc[market_signal['signal_weight'] > 0, 'signal_weight'] = 1

# %%
market_signal = market_signal.fillna(0)

# %%
signal = market_signal['signal_weight']

# %%
def singal_refine(signal, window, refine_func, func_paras):
    new_signal = signal.rolling(window).apply(refine_func, args = func_paras)
    return new_signal

# %%
signal.tail()
# Out:
# 2017-09-28    0.0
# 2017-09-29    0.0
# 2017-10-09    0.0
# 2017-10-10    0.0
# 2017-10-11    1.0
# Name: signal_weight, dtype: float64

# %%
def signal_refine_func1(x, threshold):
    signal = 0
    sum_weigth = x.sum()
    if sum_weigth > threshold:
        signal = 1
    else:
        signal = 0
    return signal

# %%
open_signal = singal_refine(signal, 2, signal_refine_func1, (1,))

# %%
open_signal = new_signal.fillna(0)

# %%
def merge_signal(market, signal, func):
    pass

# %%
market_signal = pd.concat([idx_return_close, open_signal],axis=1)

# %%
market_signal.cloumns = ['price', 'signal']

# %%
market_signal['new_signal'] = 0

# %%
market_signal.head()
# Out:
#                close  signal_weight  new_signal
# tradeDate
# 2014-01-02  1.000000            0.0           0
# 2014-01-03  0.986563            0.0           0
# 2014-01-06  0.964108            0.0           0
# 2014-01-07  0.963833            0.0           0
# 2014-01-08  0.965516            0.0           0

# %%
market_signal.index[-1]
# Out:
# '2017-10-11'

# %%
market_signal
# Out:
#                close  signal_weight  new_signal
# tradeDate
# 2014-01-02  1.000000            0.0           0
# 2014-01-03  0.986563            0.0           0
# 2014-01-06  0.964108            0.0           0
# 2014-01-07  0.963833            0.0           0
# 2014-01-08  0.965516            0.0           0
# 2014-01-09  0.957037            0.0           0
# 2014-01-10  0.949556            0.0           0
# 2014-01-13  0.944745            0.0           0
# 2014-01-14  0.953001            0.0           0
# 2014-01-15  0.951317            0.0           0
# 2014-01-16  0.952566            0.0           0
# 2014-01-17  0.938204            0.0           0
# 2014-01-20  0.932820            0.0           0
# 2014-01-21  0.942045            0.0           0
# 2014-01-22  0.966330            0.0           0
# 2014-01-23  0.961201            0.0           0
# 2014-01-24  0.967140            0.0           0
# 2014-01-27  0.954323            0.0           0
# 2014-01-28  0.956020            0.0           0
# 2014-01-29  0.959431            0.0           0
# 2014-01-30  0.948522            0.0           0
# 2014-02-07  0.952842            0.0           0
# 2014-02-10  0.976550            0.0           0
# 2014-02-11  0.984315            0.0           0
# 2014-02-12  0.986766            0.0           0
# 2014-02-13  0.981727            0.0           0
# 2014-02-14  0.988630            0.0           0
# 2014-02-17  0.995551            0.0           0
# 2014-02-18  0.982971            0.0           0
# 2014-02-19  0.994264            0.0           0
# ...              ...            ...         ...
# 2017-08-24  1.608388            1.0           0
# 2017-08-25  1.634706            0.0           0
# 2017-08-28  1.654929            0.0           0
# 2017-08-29  1.651409            1.0           0
# 2017-08-30  1.651306            1.0           0
# 2017-08-31  1.646049            1.0           0
# 2017-09-01  1.649686            0.0           0
# 2017-09-04  1.656180            0.0           0
# 2017-09-05  1.661102            0.0           0
# 2017-09-06  1.657831            0.0           0
# 2017-09-07  1.649399            0.0           0
# 2017-09-08  1.647727            0.0           0
# 2017-09-11  1.647579            1.0           0
# 2017-09-12  1.652871            0.0           0
# 2017-09-13  1.654883            0.0           0
# 2017-09-14  1.649435            0.0           0
# 2017-09-15  1.650013            0.0           0
# 2017-09-18  1.655115            0.0           0
# 2017-09-19  1.650366            1.0           0
# 2017-09-20  1.654810            1.0           0
# 2017-09-21  1.652821            1.0           0
# 2017-09-22  1.652784            1.0           0
# 2017-09-25  1.644197            1.0           0
# 2017-09-26  1.645484            0.0           0
# 2017-09-27  1.645664            0.0           0
# 2017-09-28  1.646241            0.0           0
# 2017-09-29  1.652254            0.0           0
# 2017-10-09  1.671938            0.0           0
# 2017-10-10  1.675236            0.0           0
# 2017-10-11  1.680758            0.0           0
#
# [920 rows x 3 columns]
