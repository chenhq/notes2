# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
sbn.set()

# %%
# Variable
timesteps = 64
batch_size = 2
train_to_val_ratio = 7
units = 32
data_dim = 8
div_class = [-0.5, 0.5]
#div_class = [-0.5, -0.3, -0.1, 0.1, 0.3, 0.5]
num_classes = len(div_class) + 1

# %%
def data_load():
    data_dir = '../data/'
    day_index1 = data_dir + '1day/index/2000_2009.csv'
    day_index2 = data_dir + '1day/index/2010_2016.csv'
    data1 = pd.read_csv(day_index1,encoding='gbk', parse_dates=['date'])
    data2 = pd.read_csv(day_index2,encoding='gbk', parse_dates=['date'])
    data = pd.concat([data1, data2])
    data.set_index(['code', 'date'], inplace=True)
    return data

# %%
def split_train_validate(data, timesteps, batch_size, query_str):
    match = data_all.query(query_str)
    min_num = int(batch_size) * int(timesteps) 
    size = len(data)
    m = int(size / min_num)
    if m < 1:
        return None
    
    end_num = min_num * m
    print("train set: {0}:{1}".format(0, end_num))
    train = match.iloc[:end_num, :]

    return train

# %%
def split_train_validate1(data, timesteps, batch_size, train_to_val_ratio):
    min_test_num = batch_size * timesteps 
    min_train_num = min_test_num * train_to_val_ratio
    
    min_all = min_train_num + min_test_num
    size = len(data)
    if size < min_all:
        return None, None
    
    m = int(size / min_all)
    print("train set: {0}:{1}".format(0, min_train_num*m))
    train = data.iloc[:min_train_num*m, :]
    
    test_begin = min_train_num * m
    test_end = int(size / min_test_num) * min_test_num
    print("test set: {0}:{1}".format(test_begin, test_end))
    test = data.iloc[test_begin:test_end, :]
    return train, test

# %%
def data_clean(data):
    new_data = pd.DataFrame()
    for column in ['open', 'high', 'low', 'close']:
        new_data[column] = data[column] / 10000.0

    # new_data.dropna(inplace=True)
    return new_data

# %%
# 阴阳线
def stick_type(x):
    stick_type = -1
    if x['close'] >= x['open']:
        stick_type = 1
    return stick_type

# 上引线
def up_line(x):
    return x['high'] - x[['open','close']].max()

# 下引线
def down_line(x):
    return x[['open','close']].min() - x['low']

# 实体长度
def body_size(x):
    return x['close'] - x['open']

def range_to_class(x):
    cls = []
    size = len(div_class)
    n = -1;
    if x < div_class[0]:
        n = 1
    elif x >= div_class[size-1]:
        n = size + 1
    else:    
        for i in range(0, size-1):
            if div_class[i] <= x < div_class[i+1]:
                n = i + 2
                # print("n=", n)
                break
    if n >= 0:
        for i in range(0, size+1):
            if i == n - 1:
                cls.append(1.0)
            else:
                cls.append(0.0)
    else:
        print(x)
        print("Error: n less than 0")
    return cls

# %%
def data_transform(data):
    new_data = pd.DataFrame()
    pre_close = data['close'].shift(1)
    for column in ['open', 'high', 'low', 'close']:
        new_data[column] = (data[column] - pre_close) / pre_close
    # new_data.dropna(inplace=True)
        
    # change percentage enlarge
    new_data = new_data * 100.0
        
    # add new feature
    new_data['stick_type'] = new_data.apply(stick_type, axis=1)
    new_data['up_line'] = new_data.apply(up_line, axis=1)
    new_data['down_line'] = new_data.apply(down_line, axis=1)
    new_data['close_open'] = new_data.apply(body_size, axis=1)
        
    # classes
    new_data['class'] = new_data['close'].shift(-1)
    # new_data.dropna(inplace=True)
    new_data.fillna(0, inplace=True)
    new_data['class']= new_data['class'].map(range_to_class)
        
    # new_data.dropna(inplace=True)
    return new_data

# %%
def data_reform(data, batch_size, timesteps):
    print("shape: {0}".format(data.shape))
    size = len(data)
    if size % (int(batch_size) * int(timesteps)) != 0:
        print("data size not match, size: {0}, batch_size: {1}, timesteps: {2}".format(size, batch_size, timesteps))
        return None, None
   
    X, Y0 = data[:, :-1], data[:, -1]
    
    X = X.reshape((-1, timesteps, X.shape[1]))
    
    Y = np.array([np.array(y) for y in Y0])
    
    Y = Y.reshape((-1, timesteps, Y.shape[1]))
    
    print("X.shape: {0} Y.shape: {1}".format(X.shape, Y.shape))
    
    return X, Y

# %%
idxes = data_all.index.get_level_values('code').unique()

# %%
idxes
# Out:
# Int64Index([   300, 990009, 990017, 990018, 990019, 990020, 990021, 990022,
#             990023, 990025,
#             ...
#             399989, 399990, 399991, 399992, 399993, 399994, 399995, 399996,
#             399997, 399998],
#            dtype='int64', name='code', length=742)

# %%
data_all.query('date>"20150101"')
# Out:
#                    wind_code   name       time      open      high       low  \
# code   date
# 300    2015-01-05  000300.SH  沪深300  150049000  35660888  36690422  35515104
#        2015-01-06  000300.SH  沪深300  150049000  36084279  36832256  35872311
#        2015-01-07  000300.SH  沪深300  150056000  36209239  36711903  36016977
#        2015-01-08  000300.SH  沪深300  150058000  36500729  36599448  35520997
#        2015-01-09  000300.SH  沪深300  150053000  35475740  36897531  35363949
#        2015-01-12  000300.SH  沪深300  150052000  35315148  35605271  34613219
#        2015-01-13  000300.SH  沪深300  150054000  35064508  35501580  34947679
#        2015-01-14  000300.SH  沪深300  150057000  35229071  35472424  34715600
#        2015-01-15  000300.SH  沪深300  150059000  35017193  36041205  34822697
#        2015-01-16  000300.SH  沪深300  150049000  36162475  36621576  36012575
#        2015-01-19  000300.SH  沪深300  150057000  34140129  34972517  33309808
#        2015-01-20  000300.SH  沪深300  150056000  33367926  34192043  33256814
#        2015-01-21  000300.SH  沪深300  150056000  34204905  35577939  34094295
#        2015-01-22  000300.SH  沪深300  150059000  35510515  35767559  35200526
#        2015-01-23  000300.SH  沪深300  150054000  35820876  36278062  35486261
#        2015-01-26  000300.SH  沪深300  150052000  35801179  36116165  35593763
#        2015-01-27  000300.SH  沪深300  150047000  36140379  36162581  35100171
#        2015-01-28  000300.SH  沪深300  150056000  35472389  35833122  35123928
#        2015-01-29  000300.SH  沪深300  150050000  34749149  35055819  34539007
#        2015-01-30  000300.SH  沪深300  150055000  34968846  35142166  34319360
#        2015-02-02  000300.SH  沪深300  150058000  33601931  34072558  33470852
#        2015-02-03  000300.SH  沪深300  150057000  33886024  34417091  33607167
#        2015-02-04  000300.SH  沪深300  150057000  34461440  34768170  33995653
#        2015-02-05  000300.SH  沪深300  150046000  34879505  34879505  33668622
#        2015-02-06  000300.SH  沪深300  150054000  33523298  33740511  32859349
#        2015-02-09  000300.SH  沪深300  150051000  33057335  33765262  32985974
#        2015-02-10  000300.SH  沪深300  150046000  33450769  34071796  33395479
# 990905 2014-07-21  990905.SH  中证500  150100000  40387410  40489380  40174530
#        2014-07-22  990905.SH  中证500  150000000  40244205  40861113  40230163
#        2014-07-23  990905.SH  中证500  150100000  40830800  40946490  40420410
#        2014-07-24  990905.SH  中证500  150000000  40551452  40738627  40135550
#        2014-07-25  990905.SH  中证500  150100000  40520320  40898010  40478730
#
#                       close      volumw      turover  match_items  interest
# code   date
# 990905 2014-07-21  40302420  4418609600  40783092000            0         0
#        2014-07-22  40832876  5467301600  50308587000            0         0
#        2014-07-23  40571130  5851827600  52667952000            0         0
#        2014-07-24  40542231  6273828700  54485179000            0         0
#        2014-07-25  40898010  5504340800  49022360000            0         0

# %%
idx=990905
query_str = 'code=={0}'.format(idx)
data_slice = data_all.query(query_str).copy()

query_str = 'date>"20150101"'
raw_test = split_train_validate(data_slice, timesteps, batch_size, query_str)
test_c = data_clean(raw_test)
test_t = data_transform(test_c)
test_X, test_Y = data_reform(test_t.values, batch_size, timesteps)
print(test_X.shape, test_Y.shape)
# Out:
# train set: 0:2304
# shape: (2304, 9)
# X.shape: (36, 64, 8) Y.shape: (36, 64, 3)
# (36, 64, 8) (36, 64, 3)

# %%
raw_test.head()
# Out:
#                  wind_code   name       time      open      high       low  \
# code date
# 300  2015-01-05  000300.SH  沪深300  150049000  35660888  36690422  35515104
#      2015-01-06  000300.SH  沪深300  150049000  36084279  36832256  35872311
#      2015-01-07  000300.SH  沪深300  150056000  36209239  36711903  36016977
#      2015-01-08  000300.SH  沪深300  150058000  36500729  36599448  35520997
#      2015-01-09  000300.SH  沪深300  150053000  35475740  36897531  35363949
#
#                     close       volumw       turover  match_items  interest
# code date
# 300  2015-01-05  36415410  45119809800  519849817000     13667851         0
#      2015-01-06  36410591  42096218500  498529588000     13468182         0
#      2015-01-07  36437896  32019123200  398731720000     10656892         0
#      2015-01-08  35592589  29500304500  355831967000     10966728         0
#      2015-01-09  35467228  34998267200  430210592000     11238645         0

# %%
query_str = 'date<"20150101"'
all_loss_and_metrics = []
train_ids = []
data_all = data_load()
nb_epochs = 1000
for e in range(nb_epochs):
    for idx in idxes:
        print("idx: {0}".format(idx))
        query_str = 'code=={0}'.format(idx)
        data_slice = data_all.query(query_str).copy()

        # raw_train, raw_test = split_train_validate(data_slice, timesteps, batch_size, train_to_val_ratio)
        raw_train = split_train_validate(data_slice, timesteps, batch_size, query_str)
        if raw_train is None:
            continue
        
        train_ids.append(idx)
        train_c = data_clean(raw_train)
        # test_c = data_clean(raw_test)
        train_t = data_transform(train_c)
        # test_t = data_transform(test_c)
        train_X, train_Y = data_reform(train_t.values, batch_size, timesteps)
        # test_X, test_Y = data_reform(test_t.values, batch_size, timesteps)
        print(train_X.shape, train_Y.shape, test_X.shape, test_Y.shape)

        model.reset_states()
        # history = model.fit(train_X, train_Y, epochs=100, batch_size=batch_size, validation_data=(test_X, test_Y), verbose=1, shuffle=False)
        model.fit(train_X, train_Y, epochs=1, batch_size=batch_size, verbose=1, shuffle=False)
        loss_and_metrics = model.evaluate(test_X, test_Y, batch_size=batch_size)
        all_loss_and_metrics.append(history)
        print("loss_and_metrics: {0}".format(loss_and_metrics))
# Out:
# idx: 300
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0613 - acc: 0.4311
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0595903628402286, 0.43619791666666669]
# idx: 990009
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0527 - acc: 0.4418
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0616588493188222, 0.4236111111111111]
# idx: 990017
# train set: 0:2560
# shape: (2560, 9)
# X.shape: (40, 64, 8) Y.shape: (40, 64, 3)
# (40, 64, 8) (40, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 40/40 [==============================] - 1s - loss: 1.0651 - acc: 0.4297
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0512868762016296, 0.44835069444444442]
# idx: 990018
# train set: 0:3072
# shape: (3072, 9)
# X.shape: (48, 64, 8) Y.shape: (48, 64, 3)
# (48, 64, 8) (48, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 48/48 [==============================] - 1s - loss: 1.0785 - acc: 0.3896
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0503630273871951, 0.4470486111111111]
# idx: 990019
# train set: 0:2176
# shape: (2176, 9)
# X.shape: (34, 64, 8) Y.shape: (34, 64, 3)
# (34, 64, 8) (34, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 34/34 [==============================] - 1s - loss: 1.0715 - acc: 0.4154
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.0481294559107885, 0.44574652777777779]
# idx: 990020
# train set: 0:2304
# shape: (2304, 9)
# X.shape: (36, 64, 8) Y.shape: (36, 64, 3)
# (36, 64, 8) (36, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 36/36 [==============================] - 1s - loss: 1.0581 - acc: 0.4397
# 32/36 [=========================>....] - ETA: 0sloss_and_metrics: [1.053085790740119, 0.44835069444444442]
# idx: 990021
# train set: 0:2176
# shape: (2176, 9)
# X.shape: (34, 64, 8) Y.shape: (34, 64, 3)
# (34, 64, 8) (34, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 34/34 [==============================] - 1s - loss: 1.0707 - acc: 0.4118
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.0519287354416318, 0.4435763888888889]
# idx: 990022
# train set: 0:2176
# shape: (2176, 9)
# X.shape: (34, 64, 8) Y.shape: (34, 64, 3)
# (34, 64, 8) (34, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 34/34 [==============================] - 1s - loss: 0.3923 - acc: 0.9881
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.2479674484994676, 0.42881944444444442]
# idx: 990023
# train set: 0:1792
# shape: (1792, 9)
# X.shape: (28, 64, 8) Y.shape: (28, 64, 3)
# (28, 64, 8) (28, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 28/28 [==============================] - 1s - loss: 0.1621 - acc: 0.9838
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.4259868794017367, 0.42447916666666669]
# idx: 990025
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.2366 - acc: 0.3818
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.056098719437917, 0.44184027777777779]
# idx: 990026
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.0877 - acc: 0.3724
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.0540496475166745, 0.43663194444444442]
# idx: 990027
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.0871 - acc: 0.3859
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.0516032973925273, 0.44401041666666669]
# idx: 990028
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.0808 - acc: 0.4120
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0479915009604559, 0.45789930555555558]
# idx: 990029
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.0720 - acc: 0.4203
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.0498691995938618, 0.46354166666666669]
# idx: 990030
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.0770 - acc: 0.4042
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.0530885855356853, 0.44574652777777779]
# idx: 990031
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.0736 - acc: 0.4245
# 30/36 [========================>.....] - ETA: 0sloss_and_metrics: [1.0478634569380019, 0.45269097222222221]
# idx: 990032
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.0841 - acc: 0.3875
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0504602524969313, 0.453125]
# idx: 990033
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.0792 - acc: 0.3906
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0498800343937345, 0.44618055555555558]
# idx: 990034
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.0817 - acc: 0.3792
# 32/36 [=========================>....] - ETA: 0sloss_and_metrics: [1.0516523818174999, 0.4513888888888889]
# idx: 990035
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.0722 - acc: 0.4135
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.0590467022524939, 0.44791666666666669]
# idx: 990036
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.0774 - acc: 0.4094
# 32/36 [=========================>....] - ETA: 0sloss_and_metrics: [1.0566273265414767, 0.45052083333333331]
# idx: 990037
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.0787 - acc: 0.4010
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0524691012170579, 0.45442708333333331]
# idx: 990038
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.0785 - acc: 0.4000
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.0441157850954268, 0.45659722222222221]
# idx: 990039
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.0567 - acc: 0.4385
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0496016045411427, 0.45442708333333331]
# idx: 990040
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.0676 - acc: 0.4286
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.0556264850828383, 0.44835069444444442]
# idx: 990041
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 1.0749 - acc: 0.4115
# 32/36 [=========================>....] - ETA: 0sloss_and_metrics: [1.0426436463991802, 0.4587673611111111]
# idx: 990042
# train set: 0:1792
# shape: (1792, 9)
# X.shape: (28, 64, 8) Y.shape: (28, 64, 3)
# (28, 64, 8) (28, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 28/28 [==============================] - 1s - loss: 1.0792 - acc: 0.4068
# 32/36 [=========================>....] - ETA: 0sloss_and_metrics: [1.0476361778047349, 0.4548611111111111]
# idx: 990043
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0763 - acc: 0.3960
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.0514765282471974, 0.44618055555555558]
# idx: 990044
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0610 - acc: 0.4276
# 32/36 [=========================>....] - ETA: 0sloss_and_metrics: [1.0513269901275635, 0.44921875]
# idx: 990045
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0537 - acc: 0.4293
# 30/36 [========================>.....] - ETA: 0sloss_and_metrics: [1.0524469912052155, 0.4453125]
# idx: 990046
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0541 - acc: 0.4290
# 32/36 [=========================>....] - ETA: 0sloss_and_metrics: [1.0533310108714633, 0.44184027777777779]
# idx: 990047
# train set: 0:1792
# shape: (1792, 9)
# X.shape: (28, 64, 8) Y.shape: (28, 64, 3)
# (28, 64, 8) (28, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 28/28 [==============================] - 1s - loss: 1.0776 - acc: 0.4090
# 30/36 [========================>.....] - ETA: 0sloss_and_metrics: [1.049642887380388, 0.4552951388888889]
# idx: 990048
# train set: 0:1792
# shape: (1792, 9)
# X.shape: (28, 64, 8) Y.shape: (28, 64, 3)
# (28, 64, 8) (28, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 28/28 [==============================] - 1s - loss: 1.0846 - acc: 0.4107
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.0495793256494734, 0.44878472222222221]
# idx: 990049
# train set: 0:1664
# shape: (1664, 9)
# X.shape: (26, 64, 8) Y.shape: (26, 64, 3)
# (26, 64, 8) (26, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 26/26 [==============================] - 0s - loss: 1.0791 - acc: 0.3888
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.050631946987576, 0.45442708333333331]
# idx: 990050
# train set: 0:2560
# shape: (2560, 9)
# X.shape: (40, 64, 8) Y.shape: (40, 64, 3)
# (40, 64, 8) (40, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 40/40 [==============================] - 1s - loss: 1.0641 - acc: 0.4160
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0474943651093378, 0.45572916666666669]
# idx: 990051
# train set: 0:2560
# shape: (2560, 9)
# X.shape: (40, 64, 8) Y.shape: (40, 64, 3)
# (40, 64, 8) (40, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 40/40 [==============================] - 1s - loss: 1.0562 - acc: 0.4320
# 36/36 [==============================] - 0s      ETA
# loss_and_metrics: [1.0485652287801106, 0.45572916666666669]
# idx: 990052
# train set: 0:2560
# shape: (2560, 9)
# X.shape: (40, 64, 8) Y.shape: (40, 64, 3)
# (40, 64, 8) (40, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 40/40 [==============================] - 1s - loss: 1.0653 - acc: 0.4152
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0467962788210974, 0.4513888888888889]
# idx: 990053
# train set: 0:2560
# shape: (2560, 9)
# X.shape: (40, 64, 8) Y.shape: (40, 64, 3)
# (40, 64, 8) (40, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 40/40 [==============================] - 1s - loss: 1.0591 - acc: 0.4344
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0458748539288838, 0.4587673611111111]
# idx: 990054
# train set: 0:2432
# shape: (2432, 9)
# X.shape: (38, 64, 8) Y.shape: (38, 64, 3)
# (38, 64, 8) (38, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 38/38 [==============================] - 1s - loss: 1.0692 - acc: 0.4165
# 30/36 [========================>.....] - ETA: 0sloss_and_metrics: [1.0455710921022627, 0.45269097222222221]
# idx: 990055
# train set: 0:1792
# shape: (1792, 9)
# X.shape: (28, 64, 8) Y.shape: (28, 64, 3)
# (28, 64, 8) (28, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 28/28 [==============================] - 1s - loss: 1.0812 - acc: 0.3990
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.0477436383565266, 0.4587673611111111]
# idx: 990056
# train set: 0:1792
# shape: (1792, 9)
# X.shape: (28, 64, 8) Y.shape: (28, 64, 3)
# (28, 64, 8) (28, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 28/28 [==============================] - 1s - loss: 1.0790 - acc: 0.4135
# 32/36 [=========================>....] - ETA: 0sloss_and_metrics: [1.0473179618517559, 0.45833333333333331]
# idx: 990057
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0647 - acc: 0.4311
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0463131732410855, 0.4592013888888889]
# idx: 990058
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0603 - acc: 0.4332
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.046383606062995, 0.45963541666666669]
# idx: 990059
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0584 - acc: 0.4215
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0533860690063901, 0.44835069444444442]
# idx: 990060
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0605 - acc: 0.4219
# 32/36 [=========================>....] - ETA: 0sloss_and_metrics: [1.0474154353141785, 0.4548611111111111]
# idx: 990061
# train set: 0:1920
# shape: (1920, 9)
# X.shape: (30, 64, 8) Y.shape: (30, 64, 3)
# (30, 64, 8) (30, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 30/30 [==============================] - 1s - loss: 0.3860 - acc: 0.9964
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.2173509730233087, 0.4353298611111111]
# idx: 990062
# train set: 0:2560
# shape: (2560, 9)
# X.shape: (40, 64, 8) Y.shape: (40, 64, 3)
# (40, 64, 8) (40, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 40/40 [==============================] - 1s - loss: 1.0941 - acc: 0.4121
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.0556963615947299, 0.45269097222222221]
# idx: 990063
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0663 - acc: 0.4162
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0480652650197346, 0.45442708333333331]
# idx: 990064
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0665 - acc: 0.4162
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.0477002958456676, 0.45703125]
# idx: 990065
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0578 - acc: 0.4371
# 30/36 [========================>.....] - ETA: 0sloss_and_metrics: [1.0440099073780909, 0.46440972222222221]
# idx: 990066
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0647 - acc: 0.4155
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0476769573158689, 0.45399305555555558]
# idx: 990067
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0560 - acc: 0.4364
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0517193741268582, 0.45182291666666669]
# idx: 990068
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0597 - acc: 0.4151
# 36/36 [==============================] - 0s
# loss_and_metrics: [1.0497743785381317, 0.45182291666666669]
# idx: 990069
# train set: 0:2816
# shape: (2816, 9)
# X.shape: (44, 64, 8) Y.shape: (44, 64, 3)
# (44, 64, 8) (44, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 44/44 [==============================] - 1s - loss: 1.0662 - acc: 0.4176
# 32/36 [=========================>....] - ETA: 0sloss_and_metrics: [1.0549660987324185, 0.44444444444444442]
# idx: 990091
# train set: 0:2688
# shape: (2688, 9)
# X.shape: (42, 64, 8) Y.shape: (42, 64, 3)
# (42, 64, 8) (42, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 42/42 [==============================] - 1s - loss: 1.0401 - acc: 0.4516
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0550912453068628, 0.45008680555555558]
# idx: 990092
# train set: 0:2688
# shape: (2688, 9)
# X.shape: (42, 64, 8) Y.shape: (42, 64, 3)
# (42, 64, 8) (42, 64, 3) (36, 64, 8) (36, 64, 3)
# Epoch 1/1
# 42/42 [==============================] - 1s - loss: 1.0524 - acc: 0.4342
# 34/36 [===========================>..] - ETA: 0sloss_and_metrics: [1.0439909829033747, 0.45355902777777779]
# idx: 990102
# train set: 0:2688

# %% [markdown]
# ### 分类问题

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()

# %%
# input layer
# activation='relu' 
# dropout=0.5
# kernel_initializer="uniform"
model.add(LSTM(units, stateful=True, return_sequences=True, batch_input_shape=(batch_size, timesteps, data_dim), kernel_initializer="uniform"))

# %%
# hidden layer
model.add(LSTM(units, return_sequences=True, stateful=True, dropout=0.5, kernel_initializer="uniform"))
model.add(LSTM(units, return_sequences=True, stateful=True, dropout=0.5, kernel_initializer="uniform"))
model.add(LSTM(units, return_sequences=True, stateful=True, dropout=0.5, kernel_initializer="uniform"))

# %%
#model.add(LSTM(units, activation='relu', dropout=0.5, return_sequences=True))
#model.add(LSTM(units, activation='relu', dropout=0.5, return_sequences=True))
#model.add(LSTM(units, activation='relu', dropout=0.5, return_sequences=True))
#model.add(LSTM(units, activation='relu', dropout=0.5, return_sequences=True))
#model.add(LSTM(units, activation='relu', dropout=0.5, return_sequences=True))

# %% [markdown]
# ### 回归问题

# %%
# # output layer
# # model.add(Dense(no_classes, activation='softmax'))
# model.add(Dense(1, activation='sigmoid')) # or sigmoid?

# %%
# # model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# model.compile(optimizer='RMSProp', loss='mse') #mse

# %% [markdown]
# ### 分类问题

# %%
from keras.layers import LSTM, Dense, Dropout, BatchNormalization, Activation

# %%
# output layer
model.add(Dense(num_classes, activation='softmax'))
# model.add(Dense(num_classes, kernel_initializer="uniform"))
# model.add(BatchNormalization())
# model.add(Activation('softmax'))

# %%
from keras.optimizers import SGD, Adam, RMSprop
model.compile(optimizer=RMSprop(0.0005), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (2, 64, 32)               5248
# _________________________________________________________________
# lstm_2 (LSTM)                (2, 64, 32)               8320
# _________________________________________________________________
# lstm_3 (LSTM)                (2, 64, 32)               8320
# _________________________________________________________________
# dense_1 (Dense)              (2, 64, 3)                99
# =================================================================
# Total params: 21,987
# Trainable params: 21,987
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_X, train_Y, epochs=100, batch_size=batch_size, validation_data=(test_X, test_Y), verbose=1, shuffle=False)
# Out:
# Train on 28 samples, validate on 8 samples
# Epoch 1/100
# 28/28 [==============================] - 1s - loss: 1.0252 - acc: 0.4487 - val_loss: 1.0728 - val_acc: 0.3887
# Epoch 2/100
# 28/28 [==============================] - 1s - loss: 1.0217 - acc: 0.4632 - val_loss: 1.0711 - val_acc: 0.4121
# Epoch 3/100
# 28/28 [==============================] - 1s - loss: 1.0221 - acc: 0.4548 - val_loss: 1.0680 - val_acc: 0.4102
# Epoch 4/100
# 28/28 [==============================] - 1s - loss: 1.0238 - acc: 0.4526 - val_loss: 1.0763 - val_acc: 0.4023
# Epoch 5/100
# 28/28 [==============================] - 1s - loss: 1.0234 - acc: 0.4604 - val_loss: 1.0684 - val_acc: 0.3965
# Epoch 95/100
# 28/28 [==============================] - 1s - loss: 1.0075 - acc: 0.4621 - val_loss: 1.1143 - val_acc: 0.3809
# Epoch 96/100
# 28/28 [==============================] - 1s - loss: 0.9969 - acc: 0.4782 - val_loss: 1.1098 - val_acc: 0.3867
# Epoch 97/100
# 28/28 [==============================] - 1s - loss: 0.9962 - acc: 0.4955 - val_loss: 1.1119 - val_acc: 0.4023
# Epoch 98/100
# 28/28 [==============================] - 1s - loss: 1.0002 - acc: 0.4721 - val_loss: 1.1158 - val_acc: 0.3945
# Epoch 99/100
# 28/28 [==============================] - 1s - loss: 1.0063 - acc: 0.4754 - val_loss: 1.1107 - val_acc: 0.4043
# Epoch 100/100
# 28/28 [==============================] - 1s - loss: 0.9948 - acc: 0.4788 - val_loss: 1.1136 - val_acc: 0.3926

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plt.plot(history.history['acc'], label='train')
plt.plot(history.history['val_acc'], label='test')
plt.legend()
plt.show()

# %%
predict_Y=model.predict(x=test_X,batch_size=batch_size)

# %%
predict_Y.shape

# %%
predict_value = np.argmax(predict_Y,axis=2)

# %%
predict_value.shape

# %%
test_set = idx300n.iloc[1800:2400, :].copy()

# %%
test_set.head()

# %%
def class_argmax(x):
    return np.argmax(x)

# %%
test_set['class']= test_set['class'].map(class_argmax)

# %%
test_set.head()

# %%
cmp_predict = pd.DataFrame()
cmp_predict['class'] = test_set['class']

# %%
cmp_predict['predict_class'] = predict_value.reshape((-1, ))

# %%
cmp_predict['close'] = idx300.loc[cmp_predict.index, 'close']

# %%
cmp_predict['diff'] = cmp_predict['predict_class'] - cmp_predict['class']

# %%
cmp_predict.head()

# %%
cmp_predict=cmp_predict.reset_index()

# %%
cmp_predict = cmp_predict.reset_index()

# %%
cmp_predict.head()

# %%
def color(x):
    c = 'm'
    if x < 0:
        c = 'g'
    elif x > 0:
        c = 'r'
    else:
        c = 'b'
    return c
cmp_predict['color'] = cmp_predict['diff'].map(color)

# %%
cmp_predict.plot(kind='scatter', x='index', y='close', s=60, c=cmp_predict.color, figsize=(21, 7))

# %%
idx300n['close'].head(600).plot.hist( bins=30, figsize=(21, 7))

# %%
cmp_predict.tail()

# %%
cmp_predict['predict_class'].plot.hist()

# %%
cmp_predict['class'].plot.hist()

# %%
cmp_predict['next_close'] = cmp_predict['close'].shift(-1)

# %%
cmp_predict['profit'] = cmp_predict['next_close'] - cmp_predict['close']

# %%
cmp_predict.head()

# %%
def predict_profit(x):
    profit = 0
    if x['predict_class'] == 2:
        profit = x['profit']
    elif x['predict_class'] == 0:
        profit = -x['profit']
    else:
        profit = 0
    return profit
cmp_predict['predict_profit'] = cmp_predict.apply(predict_profit, axis=1)

# %%
cmp_predict['predict_profit'].cumsum().plot(figsize=(21, 7))

# %%
cmp_predict.head(400).tail()

# %%
cmp_predict.head()

# %%
cmp_predict[cmp_predict['predict_class']==2]['predict_profit'].cumsum().plot(figsize=(21, 7))

# %%
cmp_predict[cmp_predict['predict_class']==0]['predict_profit'].cumsum().plot(figsize=(21, 7))
