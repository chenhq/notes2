# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as snb
snb.set()
import matplotlib.font_manager as fm
myfont = fm.FontProperties(fname='idx/msyh.ttf')

# %%
idx_return_df = pd.read_csv("idx_return_df.csv")

# %%
idx_return_df = idx_return_df.drop("Unnamed: 0", axis=1).set_index('tradeDate')

# %%
idx_return_df.head(100)
# Out:
#                 深证成指     沪深300     中证500      上证50      中小板指      创业板指  \
# tradeDate
# 2014-01-02  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2014-01-03  0.989394  0.986563  0.991797  0.983965  1.001831  1.014881
# 2014-01-06  0.963530  0.964108  0.964401  0.969144  0.978531  0.992742
# 2014-01-07  0.962033  0.963833  0.970317  0.967686  0.985993  1.014458
# 2014-01-08  0.961520  0.965516  0.971498  0.970683  0.992195  1.054028
# 2014-01-09  0.954691  0.957037  0.960535  0.963348  0.977318  1.035440
# 2014-01-10  0.942529  0.949556  0.943022  0.959752  0.960655  1.015228
# 2014-01-13  0.933226  0.944745  0.938704  0.957411  0.954464  1.022344
# 2014-01-14  0.944713  0.953001  0.957289  0.960404  0.968894  1.050947
# 2014-01-15  0.945087  0.951317  0.963685  0.953501  0.980855  1.061755
# 2014-01-16  0.944892  0.952566  0.965289  0.956438  0.974789  1.046632
# 2014-01-17  0.929776  0.938204  0.954270  0.945277  0.961805  1.046891
# 2014-01-20  0.927282  0.932820  0.947048  0.938340  0.952086  1.029807
# 2014-01-21  0.935798  0.942045  0.961597  0.947335  0.963340  1.055626
# 2014-01-22  0.963776  0.966330  0.987308  0.969907  0.985354  1.074072
# 2014-01-23  0.959835  0.961201  0.994180  0.960241  0.992309  1.096415
# 2014-01-24  0.968051  0.967140  1.009041  0.962184  1.008707  1.113600
# 2014-01-27  0.955406  0.954323  1.008854  0.947323  1.004661  1.108526
# 2014-01-28  0.953954  0.956020  1.006739  0.953048  0.997405  1.103778
# 2014-01-29  0.949867  0.959431  1.015741  0.957332  1.005321  1.122673
# 2014-01-30  0.933235  0.948522  1.009755  0.946349  0.994235  1.122262
# 2014-02-07  0.938650  0.952842  1.028533  0.945067  1.010327  1.149800
# 2014-02-10  0.962754  0.976550  1.058929  0.964599  1.045995  1.165350
# 2014-02-11  0.965954  0.984315  1.060423  0.979004  1.041295  1.145647
# 2014-02-12  0.973836  0.986766  1.072126  0.978158  1.053049  1.155261
# 2014-02-13  0.968294  0.981727  1.056276  0.978807  1.038530  1.114124
# 2014-02-14  0.971577  0.988630  1.074400  0.982794  1.053559  1.137120
# 2014-02-17  0.978997  0.995551  1.094823  0.985271  1.069819  1.169252
# 2014-02-18  0.965257  0.982971  1.093511  0.966333  1.064685  1.159293
# 2014-02-19  0.980227  0.994264  1.093588  0.982254  1.070015  1.158589
# ...              ...       ...       ...       ...       ...       ...
# 2014-04-18  0.918829  0.958010  1.047138  0.974492  0.953485  1.033320
# 2014-04-21  0.906242  0.941976  1.030525  0.956862  0.939424  1.023142
# 2014-04-22  0.910878  0.946089  1.025804  0.966977  0.934196  1.002389
# 2014-04-23  0.916240  0.945172  1.021126  0.965372  0.934535  0.995075
# 2014-04-24  0.914357  0.943363  1.009598  0.967450  0.922894  0.989874
# 2014-04-25  0.902552  0.933613  0.987734  0.961532  0.906076  0.969167
# 2014-04-28  0.892299  0.919461  0.957565  0.950469  0.885124  0.943181
# 2014-04-29  0.904549  0.929582  0.971685  0.958305  0.895092  0.950143
# 2014-04-30  0.901222  0.929663  0.978765  0.957536  0.899770  0.962645
# 2014-05-05  0.900814  0.928720  0.987112  0.952875  0.908842  0.976852
# 2014-05-06  0.901101  0.929091  0.992230  0.951413  0.918101  0.987888
# 2014-05-07  0.891588  0.920473  0.974554  0.945601  0.900927  0.967759
# 2014-05-08  0.883613  0.919689  0.975605  0.947228  0.897592  0.960116
# 2014-05-09  0.882684  0.919004  0.965733  0.948522  0.888739  0.944172
# 2014-05-12  0.901872  0.938875  0.990873  0.966234  0.911344  0.958949
# 2014-05-13  0.900908  0.936636  0.989348  0.963114  0.909234  0.957420
# 2014-05-14  0.902782  0.935568  0.988545  0.961390  0.909828  0.959233
# 2014-05-15  0.889010  0.923384  0.969973  0.953669  0.890152  0.940642
# 2014-05-16  0.892509  0.924190  0.968496  0.953005  0.889395  0.920083
# 2014-05-19  0.881334  0.910921  0.962963  0.934734  0.882610  0.921507
# 2014-05-20  0.881296  0.911192  0.965651  0.935764  0.885446  0.933717
# 2014-05-21  0.887885  0.919866  0.973870  0.944296  0.896842  0.943581
# 2014-05-22  0.885301  0.917695  0.973560  0.942638  0.896791  0.952371
# 2014-05-23  0.892356  0.925249  0.984065  0.950853  0.906206  0.972239
# 2014-05-26  0.896569  0.928509  0.994700  0.951925  0.914384  0.990815
# 2014-05-27  0.894722  0.924762  0.992319  0.947879  0.911348  0.979956
# 2014-05-28  0.909581  0.934267  1.003563  0.955581  0.926712  1.004477
# 2014-05-29  0.904759  0.928156  0.993240  0.950809  0.916201  0.985903
# 2014-05-30  0.907626  0.928716  0.995156  0.949393  0.919443  0.988840
# 2014-06-03  0.902289  0.925899  0.993461  0.946463  0.920140  0.989964
#
#                 上证综指
# tradeDate
# 2014-01-02  1.000000
# 2014-01-03  0.987555
# 2014-01-06  0.969812
# 2014-01-07  0.970574
# 2014-01-08  0.969163
# 2014-01-09  0.961238
# 2014-01-10  0.954447
# 2014-01-13  0.952677
# 2014-01-14  0.960868
# 2014-01-15  0.959211
# 2014-01-16  0.959379
# 2014-01-17  0.950489
# 2014-01-20  0.943996
# 2014-01-21  0.952084
# 2014-01-22  0.972675
# 2014-01-23  0.968139
# 2014-01-24  0.973928
# 2014-01-27  0.963929
# 2014-01-28  0.966401
# 2014-01-29  0.971806
# 2014-01-30  0.963826
# 2014-02-07  0.969238
# 2014-02-10  0.988945
# 2014-02-11  0.997290
# 2014-02-12  1.000269
# 2014-02-13  0.994792
# 2014-02-14  1.003063
# 2014-02-17  1.012339
# 2014-02-18  1.004589
# 2014-02-19  1.015724
# ...              ...
# 2014-04-18  0.994482
# 2014-04-21  0.979349
# 2014-04-22  0.982670
# 2014-04-23  0.980087
# 2014-04-24  0.975180
# 2014-04-25  0.965455
# 2014-04-28  0.949796
# 2014-04-29  0.957786
# 2014-04-30  0.960638
# 2014-05-05  0.961110
# 2014-05-06  0.961435
# 2014-05-07  0.952923
# 2014-05-08  0.955384
# 2014-05-09  0.953422
# 2014-05-12  0.973207
# 2014-05-13  0.972191
# 2014-05-14  0.970856
# 2014-05-15  0.959982
# 2014-05-16  0.960708
# 2014-05-19  0.950600
# 2014-05-20  0.951992
# 2014-05-21  0.959971
# 2014-05-22  0.958233
# 2014-05-23  0.964531
# 2014-05-26  0.967805
# 2014-05-27  0.964529
# 2014-05-28  0.971954
# 2014-05-29  0.967388
# 2014-05-30  0.966732
# 2014-06-03  0.966302
#
# [100 rows x 7 columns]

# %%
def polyfit(y, n, deg=2):
    x = np.linspace(0, 1, n)
    reg = np.polyfit(x, y, deg)
    if deg == 1:
        return reg[0]
    elif deg == 2:
        return reg[0] * 2 + reg[1]

# %%
def distance_to_plant(x):
    return (x[-1] - x[0]) / x[0]

# %%
def fit2(df, n1, n2, n3, n4):
    r0 = idx_return_df.rolling(30).mean()
    r1 = r0.rolling(n1, min_periods=n1).apply(myfit,args=(n1,))
    r2 = r1.rolling(n2).mean()
#     r3 = r2.rolling(n3, min_periods=n3).apply(myfit,args=(n3,))
#     r4 = r3.rolling(n4, min_periods=n4).mean()
    return r2

# %%
def distance(df, n_average, n_days_ago):
    ma = df.rolling(n_average).mean()
    ma = ma.dropna()
    n = n_days_ago
    d = ma.rolling(n, min_periods=n).apply(distance_to_plant)
    return d

# %%
def velocity(distance, n_point):
    n = n_point
    v = distance.rolling(n, min_periods=n).apply(polyfit, args=(n,))
    return v

# %%
begin_date = "2014-01-01"
end_date = "2016-01-01"
idx = "沪深300"

# %%
idx_return_df.rolling??

# %%
ax = idx_return_df.loc[begin_date:end_date, idx].plot(figsize=(21, 7))
legend = ax.legend()
for text in legend.texts:
    text.set_font_properties(myfont)

# %%
# ax = v.loc[begin_date:end_date, idx].plot(figsize=(21, 7))
# a.loc[begin_date:end_date, idx].plot(figsize=(21, 7))
# legend = ax.legend()
# for text in legend.texts:
#     text.set_font_properties(myfont)

# %%
d = distance(idx_return_df, 6, 3)
ax = d.loc[begin_date:end_date, idx].plot(figsize=(21, 7))
v.loc[begin_date:end_date, idx].rolling(3).mean().plot(figsize=(21, 7))
a.loc[begin_date:end_date, idx].rolling(3).mean().plot(figsize=(21, 7))
legend = ax.legend()
for text in legend.texts:
    text.set_font_properties(myfont)

# %%
v = velocity(d, 3)
ax = v.loc[begin_date:end_date, idx].plot(figsize=(21, 7))
#a.loc[begin_date:end_date, idx].plot(figsize=(21, 7))
legend = ax.legend()
for text in legend.texts:
    text.set_font_properties(myfont)

# %%
a = velocity(v, 10)
ax = a.loc[begin_date:end_date, idx].plot(figsize=(21, 7))
legend = ax.legend()
for text in legend.texts:
    text.set_font_properties(myfont)

# %%
up_cond = (d[idx] > 0) #& (v[idx] > 0) # & (a[idx]>0)

# %%
up = idx_return_df[up_cond.index.values[0]:][up_cond==True][idx]

# %%
down_cond = (d[idx] < 0) #& (v[idx] < 0) # & (a[idx]<0)

# %%
down = idx_return_df[down_cond.index.values[0]:][down_cond==True][idx]

# %%
up.head()
# Out:
# tradeDate
# 2014-01-22    0.966330
# 2014-01-23    0.961201
# 2014-01-24    0.967140
# 2014-01-27    0.954323
# 2014-01-28    0.956020
# Name: 沪深300, dtype: float64

# %%
down.head()
# Out:
# tradeDate
# 2014-01-13    0.944745
# 2014-01-14    0.953001
# 2014-01-15    0.951317
# 2014-01-16    0.952566
# 2014-01-17    0.938204
# Name: 沪深300, dtype: float64

# %%
zh_return = idx_return_df[idx] - idx_return_df[idx].shift(1)
zh_return_signal = pd.concat([zh_return, up, down], axis=1)
zh_return_signal.columns = ['idx', 'long', 'short']
zh_return_signal['long'] = zh_return_signal['long'].shift(1)
zh_return_signal['short'] = zh_return_signal['short'].shift(1)
zh_return_signal.tail()
zh_return_signal = zh_return_signal.fillna(0)
def cal_profit(x):
    if x['long'] > 0:
        profit = x['idx']
    elif x['short'] > 0:
        profit = -x['idx']
    else:
        profit = 0
    return profit

zh_return_signal['profit'] = zh_return_signal.apply(cal_profit, axis=1)
begin_date = "2017-01-01"
end_date = "2018-01-01"
(zh_return_signal[zh_return_signal['long'] > 0]['profit'] + 1)[begin_date:end_date].cumprod().plot(figsize=(21, 7))

# %%
def fixed_stop_loss(df, min_return, stop_loss, withdraw, withdraw_percent, column='close'):
    init = df.iloc[0][column]
    max_return = -1
    for idx, row in df.iterrows():
        return_ = row[column] - init
        #print(return_)
        
        if return_ >= max_return:
            # 盈利创新高，继续持仓
            max_return = return_
        else:
            # 盈利下降
            if return_ > min_return:
                # 盈利大于最小盈利
                if return_ * (1 + withdraw_percent) < max_return and (max_return - return_) > withdraw:
                    # 回撤大于固定回撤和回撤百分比
                    break
            else:
                if return_ < init * (- stop_loss):
                    # 止损
                    break
                
    return idx, return_

# %%
def fixed_stop_loss(market, open_signal, min_return, stop_loss, withdraw, withdraw_percent):
    df = pd.concat([market, open_signal], axis=1)
    df.columns = ['price', 'signal']
    df['new_signal'] = 0
    open_status = False
    for idx, row in df.iterrows():
        if open_status:
            df.loc[idx,'new_signal'] = 1
            
            return_ = row['price'] - init
            #print(return_)

            if return_ >= max_return:
                # 盈利创新高，继续持仓
                max_return = return_
            else:
                # 盈利下降
                if return_ > min_return:
                    # 盈利大于最小盈利
                    if return_ * (1 + withdraw_percent) < max_return and (max_return - return_) > withdraw:
                        # 回撤大于固定回撤和回撤百分比, 止盈
                        open_status = False
                else:
                    if return_ < init * (- stop_loss):
                        # 止损
                        open_status = False
        else:
            if df.loc[idx, 'signal'] == 1:
                open_status = True
                init = df.loc[idx]['price']
                max_return = 0
                df.loc[idx, 'new_signal'] = 1
            else:
                df.loc[idx, 'new_signal'] = 0

    
    return df['new_signal']

# %%
idx_return_df.head()

# %%
up.head()

# %%
idx_return_df.head()

# %%
idx

# %%
idx_return_close = idx_return_df[idx]

# %%
idx_return_close.head()

# %%
idx_return_close.name = 'close'

# %%
up.name = 'signal_weight'

# %%
market_signal = pd.concat([idx_return_close, up], axis=1)

# %%
market_signal['signal_weight'] = market_signal['signal_weight'].shift(1)

# %%
market_signal.loc[market_signal['signal_weight'] > 0, 'signal_weight'] = 1

# %%
market_signal = market_signal.fillna(0)

# %%
signal = market_signal['signal_weight']

# %%
def singal_refine(signal, window, refine_func, func_paras):
    new_signal = signal.rolling(window).apply(refine_func, args = func_paras)
    return new_signal

# %%
signal.tail()

# %%
def signal_refine_func1(x, threshold):
    signal = 0
    sum_weigth = x.sum()
    if sum_weigth > threshold:
        signal = 1
    else:
        signal = 0
    return signal

# %%
open_signal = singal_refine(signal, 2, signal_refine_func1, (1,))

# %%
open_signal = open_signal.fillna(0)

# %%
open_signal.head()

# %%
#fixed_stop_loss(market, open_signal, min_return, stop_loss, withdraw, withdraw_percent):
signal = fixed_stop_loss(idx_return_close, open_signal, 0.003, 0.003, 0.005, 0.1)

# %%
zh_return = idx_return_df[idx] - idx_return_df[idx].shift(1)
zh_return_signal = pd.concat([zh_return, signal], axis=1)
zh_return_signal.columns = ['profit', 'long']
# zh_return_signal['long'] = zh_return_signal['long'].shift(1)
# zh_return_signal['short'] = zh_return_signal['short'].shift(1)
# zh_return_signal.tail()
# zh_return_signal = zh_return_signal.fillna(0)
# def cal_profit(x):
#     if x['long'] > 0:
#         profit = x['idx']
#     elif x['short'] > 0:
#         profit = -x['idx']
#     else:
#         profit = 0
#     return profit

# zh_return_signal['profit'] = zh_return_signal.apply(cal_profit, axis=1)
begin_date = "2016-01-01"
end_date = "2017-01-01"
(zh_return_signal[zh_return_signal['long'] > 0]['profit'] + 1)[begin_date:end_date].cumprod().plot(figsize=(21, 7))
(zh_return_signal[zh_return_signal['long'] > 0]['profit'] + 1)[begin_date:end_date].cumprod().plot(figsize=(21, 7))

# %%
df.plot(kind='scatter', x='col1', y='col2', s=df.col3)
