# %%
# Stateful LSTM to learn one-char to one-char mapping
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.utils import np_utils

# %%
# fix random seed for reproducibility
numpy.random.seed(7)
# define the raw dataset
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
# create mapping of characters to integers (0-25) and the reverse
char_to_int = dict((c, i) for i, c in enumerate(alphabet))
int_to_char = dict((i, c) for i, c in enumerate(alphabet))
# prepare the dataset of input to output pairs encoded as integers
seq_length = 1
dataX = []
dataY = []

# %%
for i in range(0, len(alphabet) - seq_length, 1):
	seq_in = alphabet[i:i + seq_length]
	seq_out = alphabet[i + seq_length]
	dataX.append([char_to_int[char] for char in seq_in])
	dataY.append(char_to_int[seq_out])
	print(seq_in, '->', seq_out)
# Out:
# A -> B
# B -> C
# C -> D
# D -> E
# E -> F
# F -> G
# G -> H
# H -> I
# I -> J
# J -> K
# K -> L
# L -> M
# M -> N
# N -> O
# O -> P
# P -> Q
# Q -> R
# R -> S
# S -> T
# T -> U
# U -> V
# V -> W
# W -> X
# X -> Y
# Y -> Z

# %%
# reshape X to be [samples, time steps, features]
X = numpy.reshape(dataX, (len(dataX), seq_length, 1))
# normalize
X = X / float(len(alphabet))
# one hot encode the output variable
y = np_utils.to_categorical(dataY)

# %%
print(X.shape, y.shape)
# Out:
# (25, 1, 1) (25, 26)

# %%
# create and fit the model
batch_size = 1
model = Sequential()
model.add(LSTM(16, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
for i in range(300):
	model.fit(X, y, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
	model.reset_states()
# Out:
# Epoch 1/1
# 0s - loss: 1.1762 - acc: 0.6800
# Epoch 1/1
# 0s - loss: 1.1712 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1745 - acc: 0.6800
# Epoch 1/1
# 0s - loss: 1.1716 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1709 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1694 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1692 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1615 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1653 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1607 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1621 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1587 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1605 - acc: 0.6800
# Epoch 1/1
# 0s - loss: 1.1559 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1552 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1539 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1778 - acc: 0.6400
# Epoch 1/1
# 0s - loss: 1.1698 - acc: 0.6400
# Epoch 1/1
# 0s - loss: 1.1692 - acc: 0.6400
# Epoch 1/1
# 0s - loss: 1.1401 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1393 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.1383 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1407 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1356 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1319 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1314 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1297 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1254 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.1264 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.1197 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.1224 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.1230 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.1167 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.1184 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.1355 - acc: 0.6400
# Epoch 1/1
# 0s - loss: 1.1355 - acc: 0.6400
# Epoch 1/1
# 0s - loss: 1.1316 - acc: 0.6400
# Epoch 1/1
# 0s - loss: 1.1267 - acc: 0.6400
# Epoch 1/1
# 0s - loss: 1.1060 - acc: 0.8000
# Epoch 1/1
# 0s - loss: 1.1055 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.1058 - acc: 0.8000
# Epoch 1/1
# 0s - loss: 1.1058 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.1073 - acc: 0.6800
# Epoch 1/1
# 0s - loss: 1.1055 - acc: 0.6800
# Epoch 1/1
# 0s - loss: 1.1080 - acc: 0.6800
# Epoch 1/1
# 0s - loss: 1.1050 - acc: 0.6800
# Epoch 1/1
# 0s - loss: 1.1082 - acc: 0.6800
# Epoch 1/1
# 0s - loss: 1.1237 - acc: 0.6000
# Epoch 1/1
# 0s - loss: 1.1162 - acc: 0.6000
# Epoch 1/1
# 0s - loss: 1.1140 - acc: 0.6000
# Epoch 1/1
# 0s - loss: 1.1102 - acc: 0.6000
# Epoch 1/1
# 0s - loss: 1.1136 - acc: 0.6800
# Epoch 1/1
# 0s - loss: 1.1036 - acc: 0.6800
# Epoch 1/1
# 0s - loss: 1.0871 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.0832 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.0872 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.0842 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.0821 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.0788 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.0806 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.0763 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.0652 - acc: 0.8000
# Epoch 1/1
# 0s - loss: 1.0693 - acc: 0.8000
# Epoch 1/1
# 0s - loss: 1.0638 - acc: 0.8000
# Epoch 1/1
# 0s - loss: 1.0612 - acc: 0.8000
# Epoch 1/1
# 0s - loss: 1.0747 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.0722 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.0636 - acc: 0.7200
# Epoch 1/1
# 0s - loss: 1.0622 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.0463 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.0520 - acc: 0.7600
# Epoch 1/1
# 0s - loss: 1.0343 - acc: 0.8000
# Epoch 1/1
# 0s - loss: 1.0237 - acc: 0.8800
# Epoch 1/1
# 0s - loss: 1.0139 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 1.0141 - acc: 0.8800
# Epoch 1/1
# 0s - loss: 1.0055 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 1.0064 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 1.0012 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 0.9936 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 0.9879 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 0.9887 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 0.9973 - acc: 0.8800
# Epoch 1/1
# 0s - loss: 1.0040 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.9875 - acc: 0.8800
# Epoch 1/1
# 0s - loss: 0.9840 - acc: 0.8800
# Epoch 1/1
# 0s - loss: 0.9763 - acc: 0.8800
# Epoch 1/1
# 0s - loss: 0.9834 - acc: 0.8800
# Epoch 1/1
# 0s - loss: 0.9688 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 0.9701 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 0.9640 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.9635 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.9547 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9610 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.9470 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9503 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9409 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9435 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9380 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9367 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9344 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9268 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9306 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9236 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9225 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9206 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9142 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9132 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9116 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9072 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9061 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9039 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8985 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.9008 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8926 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8968 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8916 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8878 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8894 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8809 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8858 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8797 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8771 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8773 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8722 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8715 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8680 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8678 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8657 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8644 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8627 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8595 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8588 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8581 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8570 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8555 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8535 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8517 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8498 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8503 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8450 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8466 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8517 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8478 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8463 - acc: 1.0000
# Epoch 1/1
# 0s - loss: 0.8450 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.8426 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.8446 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.8409 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.8437 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.8387 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.8380 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 0.8372 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 0.8382 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.8402 - acc: 0.8800
# Epoch 1/1
# 0s - loss: 0.8425 - acc: 0.8800
# Epoch 1/1
# 0s - loss: 0.8405 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8425 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8412 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8400 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8416 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8424 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8369 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8380 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8408 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8463 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8443 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8422 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8387 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8424 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8455 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8419 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8420 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8367 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8376 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8422 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8398 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8408 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8380 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8459 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8428 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8322 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8325 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8372 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8332 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8381 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8329 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8325 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8310 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8329 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8334 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8334 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8319 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8259 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8323 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8265 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8231 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8272 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8270 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8268 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8246 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8212 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8210 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8194 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8224 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8264 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8218 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8146 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8117 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8136 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8154 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8062 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8122 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8058 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7982 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8007 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7955 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7952 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7934 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7888 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7884 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7957 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7912 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.8148 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7974 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7825 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7819 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7763 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7786 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7722 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7693 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7689 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7660 - acc: 0.8800
# Epoch 1/1
# 0s - loss: 0.7646 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7678 - acc: 0.8400
# Epoch 1/1
# 0s - loss: 0.7638 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 0.7680 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 0.7655 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 0.7608 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7517 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7454 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7437 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7463 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7546 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 0.7540 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7472 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7386 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7371 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7340 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7294 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7275 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7255 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7246 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7230 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7261 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7236 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7206 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7249 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7215 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7175 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7109 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7095 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7082 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7023 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7020 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6999 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6976 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6957 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6969 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6931 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6959 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6977 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6972 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6923 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6921 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6900 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6870 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6898 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6883 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6868 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6878 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6856 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6856 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6946 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6958 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6920 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6938 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6917 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6902 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6905 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6889 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6931 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 0.6883 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6910 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 0.6912 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 0.6906 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.6890 - acc: 0.9600
# Epoch 1/1
# 0s - loss: 0.7052 - acc: 0.8800
# Epoch 1/1
# 0s - loss: 0.7008 - acc: 0.8800
# Epoch 1/1
# 0s - loss: 0.6957 - acc: 0.9200
# Epoch 1/1
# 0s - loss: 0.7014 - acc: 0.8800

# %%
# summarize performance of the model
scores = model.evaluate(X, y, batch_size=batch_size, verbose=0)
model.reset_states()
print("Model Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Model Accuracy: 92.00%

# %%
# demonstrate some model predictions
seed = [char_to_int[alphabet[0]]]
for i in range(0, len(alphabet)-1):
	x = numpy.reshape(seed, (1, len(seed), 1))
	x = x / float(len(alphabet))
	prediction = model.predict(x, verbose=0)
	index = numpy.argmax(prediction)
	print(int_to_char[seed[0]], "->", int_to_char[index])
	seed = [index]
# Out:
# A -> B
# B -> C
# C -> D
# D -> E
# E -> F
# F -> G
# G -> H
# H -> I
# I -> J
# J -> K
# K -> L
# L -> M
# M -> N
# N -> O
# O -> P
# P -> Q
# Q -> Q
# Q -> S
# S -> S
# S -> U
# U -> V
# V -> W
# W -> X
# X -> Y
# Y -> Z

# %%
model.reset_states()
# demonstrate a random starting point
letter = "K"
seed = [char_to_int[letter]]
print("New start: ", letter)
for i in range(0, 5):
	x = numpy.reshape(seed, (1, len(seed), 1))
	x = x / float(len(alphabet))
	prediction = model.predict(x, verbose=0)
	index = numpy.argmax(prediction)
	print(int_to_char[seed[0]], "->", int_to_char[index])
	seed = [index]
model.reset_states()
# Out:
# New start:  K
# K -> B
# B -> C
# C -> D
# D -> E
# E -> F

# %%
# prepare the dataset of input to output pairs encoded as integers
num_inputs = 1000
max_len = 5
dataX = []
dataY = []
for i in range(num_inputs):
	start = numpy.random.randint(len(alphabet)-2)
	end = numpy.random.randint(start, min(start+max_len,len(alphabet)-1))
	sequence_in = alphabet[start:end+1]
	sequence_out = alphabet[end + 1]
	dataX.append([char_to_int[char] for char in sequence_in])
	dataY.append(char_to_int[sequence_out])
	print(sequence_in, '->', sequence_out)
# Out:
# EFGH -> I
# STU -> V
# PQ -> R
# ABCD -> E
# D -> E
# CDEF -> G
# CDEFG -> H
# LMNOP -> Q
# FGH -> I
# JKLM -> N
# DEFGH -> I
# A -> B
# NOPQ -> R
# C -> D
# MN -> O
# STUV -> W
# HI -> J
# WXY -> Z
# V -> W
# EFGH -> I
# KLMN -> O
# UVWXY -> Z
# MNOP -> Q
# P -> Q
# GH -> I
# O -> P
# BCD -> E
# DEF -> G
# MN -> O
# KLMNO -> P
# DEF -> G
# FGH -> I
# TU -> V
# PQRS -> T
# RSTUV -> W
# A -> B
# VW -> X
# X -> Y
# ABCDE -> F
# DEF -> G
# RSTUV -> W
# GHI -> J
# UVWX -> Y
# GHI -> J
# DEFG -> H
# N -> O
# HIJK -> L
# VWX -> Y
# CDE -> F
# XY -> Z
# CDEFG -> H
# FGH -> I
# TUVW -> X
# MNO -> P
# A -> B
# IJKLM -> N
# UVWX -> Y
# RS -> T
# OPQ -> R
# I -> J
# PQRST -> U
# NOP -> Q
# IJK -> L
# CD -> E
# A -> B
# EF -> G
# IJ -> K
# OP -> Q
# LMNOP -> Q
# KLMNO -> P
# STU -> V
# O -> P
# BC -> D
# J -> K
# IJKL -> M
# MNOPQ -> R
# VW -> X
# BCD -> E
# FGH -> I
# GHI -> J
# GHI -> J
# OPQ -> R
# NOP -> Q
# IJKLM -> N
# DEF -> G
# IJKLM -> N
# NOPQR -> S
# UVW -> X
# PQRS -> T
# KLM -> N
# UVW -> X
# TU -> V
# DE -> F
# VWXY -> Z
# DEFG -> H
# EFGHI -> J
# JK -> L
# LM -> N
# STU -> V
# MNOPQ -> R
# BCDEF -> G
# OP -> Q
# IJKL -> M
# I -> J
# NOPQR -> S
# KL -> M
# LMN -> O
# OPQ -> R
# BCD -> E
# P -> Q
# N -> O
# PQRST -> U
# MNOP -> Q
# OPQRS -> T
# LMN -> O
# G -> H
# D -> E
# A -> B
# D -> E
# BCDEF -> G
# IJ -> K
# TUVWX -> Y
# BCDEF -> G
# T -> U
# ABCDE -> F
# DEF -> G
# PQRS -> T
# JKLMN -> O
# R -> S
# LMNO -> P
# E -> F
# HIJK -> L
# NOPQR -> S
# BCDEF -> G
# ABCD -> E
# AB -> C
# C -> D
# CDE -> F
# XY -> Z
# CDEF -> G
# UV -> W
# QRST -> U
# BCD -> E
# DEFG -> H
# MN -> O
# LM -> N
# BCDE -> F
# DEFG -> H
# UVWXY -> Z
# HI -> J
# EFGHI -> J
# CDEFG -> H
# LMNO -> P
# I -> J
# MNOPQ -> R
# OPQ -> R
# JKL -> M
# NO -> P
# NOPQ -> R
# MNOPQ -> R
# LM -> N
# PQR -> S
# EFG -> H
# XY -> Z
# F -> G
# BCDE -> F
# UVW -> X
# D -> E
# QRSTU -> V
# GHIJK -> L
# DEFGH -> I
# DEFGH -> I
# XY -> Z
# XY -> Z
# KLM -> N
# L -> M
# XY -> Z
# X -> Y
# TUVWX -> Y
# G -> H
# FGHIJ -> K
# CD -> E
# N -> O
# FGHI -> J
# Q -> R
# V -> W
# HI -> J
# L -> M
# NO -> P
# IJKL -> M
# A -> B
# TUVW -> X
# OP -> Q
# QRSTU -> V
# HIJKL -> M
# OPQ -> R
# C -> D
# Q -> R
# XY -> Z
# X -> Y
# NO -> P
# PQRS -> T
# OPQ -> R
# F -> G
# WX -> Y
# JKL -> M
# IJKL -> M
# KLMNO -> P
# UVW -> X
# UVWX -> Y
# UVWX -> Y
# TUVW -> X
# XY -> Z
# RS -> T
# QRS -> T
# N -> O
# M -> N
# IJ -> K
# ST -> U
# DE -> F
# BCD -> E
# OPQ -> R
# FGHI -> J
# BCDE -> F
# BCDE -> F
# QRS -> T
# STU -> V
# JKL -> M
# KLMNO -> P
# GH -> I
# DEFGH -> I
# C -> D
# KL -> M
# CD -> E
# UV -> W
# CDE -> F
# RSTUV -> W
# UVWXY -> Z
# ABCDE -> F
# TUVW -> X
# EFGH -> I
# NOPQR -> S
# XY -> Z
# STU -> V
# GH -> I
# JKL -> M
# BCDEF -> G
# FGHI -> J
# U -> V
# PQR -> S
# X -> Y
# GHI -> J
# K -> L
# PQRS -> T
# RST -> U
# CDEF -> G
# JKLM -> N
# WXY -> Z
# MNO -> P
# P -> Q
# MNOPQ -> R
# DEF -> G
# S -> T
# GHIJK -> L
# E -> F
# TUVWX -> Y
# STUVW -> X
# E -> F
# MNOPQ -> R
# IJKL -> M
# W -> X
# XY -> Z
# S -> T
# STUVW -> X
# ABCDE -> F
# NO -> P
# U -> V
# JKLMN -> O
# OPQR -> S
# EF -> G
# UVWXY -> Z
# DE -> F
# X -> Y
# FGHIJ -> K
# KLMNO -> P
# FGHI -> J
# EFGHI -> J
# BC -> D
# RS -> T
# Q -> R
# TU -> V
# NOPQR -> S
# LM -> N
# A -> B
# DEF -> G
# PQ -> R
# OPQR -> S
# I -> J
# RSTUV -> W
# KLM -> N
# NOPQR -> S
# NO -> P
# ABCDE -> F
# RST -> U
# W -> X
# C -> D
# MNOPQ -> R
# G -> H
# X -> Y
# IJ -> K
# W -> X
# IJK -> L
# IJKL -> M
# NOPQR -> S
# FGHI -> J
# KLM -> N
# IJK -> L
# TUV -> W
# K -> L
# OPQ -> R
# Q -> R
# MN -> O
# B -> C
# NOPQR -> S
# D -> E
# OP -> Q
# F -> G
# RSTU -> V
# GHIJ -> K
# W -> X
# NOPQR -> S
# EFGH -> I
# C -> D
# M -> N
# IJ -> K
# DE -> F
# C -> D
# W -> X
# QRSTU -> V
# MNOPQ -> R
# MN -> O
# F -> G
# WXY -> Z
# JKLM -> N
# MNOP -> Q
# ABC -> D
# NOPQR -> S
# C -> D
# TUVW -> X
# RS -> T
# J -> K
# TUV -> W
# E -> F
# OPQR -> S
# VW -> X
# A -> B
# OP -> Q
# LMNOP -> Q
# OPQ -> R
# TUVW -> X
# XY -> Z
# RSTUV -> W
# LMN -> O
# QRSTU -> V
# HI -> J
# VWXY -> Z
# BCDE -> F
# UVWXY -> Z
# E -> F
# X -> Y
# JK -> L
# FGHIJ -> K
# RS -> T
# MNOPQ -> R
# QRST -> U
# M -> N
# EF -> G
# K -> L
# S -> T
# WXY -> Z
# H -> I
# BCDE -> F
# G -> H
# RSTUV -> W
# ABCDE -> F
# B -> C
# M -> N
# QRST -> U
# TUVWX -> Y
# NO -> P
# R -> S
# NOPQR -> S
# IJKLM -> N
# EFG -> H
# A -> B
# UVWXY -> Z
# CDE -> F
# NOPQ -> R
# P -> Q
# GHIJ -> K
# K -> L
# EFG -> H
# H -> I
# L -> M
# X -> Y
# CDE -> F
# X -> Y
# NOPQR -> S
# E -> F
# XY -> Z
# X -> Y
# IJKL -> M
# NO -> P
# STUVW -> X
# WX -> Y
# ABCDE -> F
# DEF -> G
# PQR -> S
# ST -> U
# MNOP -> Q
# MNOP -> Q
# STUVW -> X
# STUV -> W
# TUV -> W
# EFGHI -> J
# UVW -> X
# FGHI -> J
# CDE -> F
# Q -> R
# OP -> Q
# H -> I
# KLMN -> O
# JKLM -> N
# GHIJK -> L
# OPQ -> R
# QR -> S
# STUV -> W
# VW -> X
# F -> G
# MNOP -> Q
# QRST -> U
# KLMNO -> P
# DE -> F
# BCDE -> F
# FG -> H
# GHIJ -> K
# XY -> Z
# I -> J
# A -> B
# EFGHI -> J
# NO -> P
# B -> C
# C -> D
# ST -> U
# T -> U
# NOPQ -> R
# NOPQR -> S
# JK -> L
# F -> G
# JK -> L
# X -> Y
# ABC -> D
# NO -> P
# IJ -> K
# J -> K
# KL -> M
# MN -> O
# X -> Y
# NO -> P
# GHIJK -> L
# FG -> H
# NOPQR -> S
# JK -> L
# ST -> U
# KLMN -> O
# CDEFG -> H
# GHIJ -> K
# MNOP -> Q
# OPQRS -> T
# LMNO -> P
# KL -> M
# GHI -> J
# NOP -> Q
# PQ -> R
# VWXY -> Z
# H -> I
# OPQRS -> T
# QRST -> U
# VW -> X
# VWX -> Y
# UVW -> X
# LMNO -> P
# I -> J
# TU -> V
# G -> H
# EFG -> H
# Q -> R
# VWX -> Y
# MNOPQ -> R
# NOPQR -> S
# TUV -> W
# KLMNO -> P
# F -> G
# PQRS -> T
# RS -> T
# HIJKL -> M
# F -> G
# N -> O
# XY -> Z
# X -> Y
# LMNO -> P
# EF -> G
# STUVW -> X
# XY -> Z
# UV -> W
# D -> E
# TUVW -> X
# BCDE -> F
# NOP -> Q
# BCD -> E
# ABC -> D
# O -> P
# X -> Y
# XY -> Z
# EFGHI -> J
# IJKL -> M
# UVWX -> Y
# OP -> Q
# JKLM -> N
# O -> P
# EFGH -> I
# JKL -> M
# LMNO -> P
# H -> I
# HIJ -> K
# W -> X
# MN -> O
# H -> I
# GHI -> J
# HIJKL -> M
# GHIJ -> K
# ST -> U
# ABCD -> E
# MNO -> P
# JKLMN -> O
# ST -> U
# ABCDE -> F
# IJ -> K
# FGHIJ -> K
# KLMNO -> P
# A -> B
# BCD -> E
# VWX -> Y
# ABCDE -> F
# PQRST -> U
# FGHIJ -> K
# BC -> D
# PQRST -> U
# X -> Y
# VW -> X
# TUVWX -> Y
# S -> T
# KLMN -> O
# KLM -> N
# HIJKL -> M
# EFGH -> I
# F -> G
# WXY -> Z
# WXY -> Z
# V -> W
# TUV -> W
# R -> S
# TUVW -> X
# A -> B
# KLM -> N
# WXY -> Z
# O -> P
# LMNO -> P
# NOP -> Q
# EF -> G
# B -> C
# H -> I
# PQR -> S
# EF -> G
# A -> B
# CDEF -> G
# EFGH -> I
# IJKL -> M
# IJ -> K
# WXY -> Z
# KLM -> N
# I -> J
# JKL -> M
# GHIJK -> L
# TUVW -> X
# HIJK -> L
# WXY -> Z
# FGHIJ -> K
# LMNO -> P
# L -> M
# WXY -> Z
# PQRST -> U
# BCDEF -> G
# S -> T
# RST -> U
# QRSTU -> V
# OPQRS -> T
# WXY -> Z
# FGHI -> J
# C -> D
# G -> H
# FGHI -> J
# KLM -> N
# KLM -> N
# QRST -> U
# TU -> V
# ST -> U
# IJ -> K
# QRST -> U
# ST -> U
# G -> H
# RSTU -> V
# BC -> D
# C -> D
# VWXY -> Z
# DE -> F
# IJKL -> M
# R -> S
# X -> Y
# GHIJ -> K
# GHI -> J
# RSTU -> V
# CDE -> F
# DEFGH -> I
# DEFG -> H
# KLMNO -> P
# HIJKL -> M
# N -> O
# E -> F
# N -> O
# KLMN -> O
# X -> Y
# IJKLM -> N
# HIJKL -> M
# O -> P
# RSTUV -> W
# C -> D
# DE -> F
# Q -> R
# NOP -> Q
# A -> B
# CDE -> F
# ABCD -> E
# KLMNO -> P
# UV -> W
# KLMNO -> P
# MNOP -> Q
# CDEF -> G
# U -> V
# EFG -> H
# A -> B
# EFGHI -> J
# UVWX -> Y
# RSTU -> V
# KL -> M
# V -> W
# KL -> M
# HIJ -> K
# PQRST -> U
# TUVW -> X
# FGHIJ -> K
# QRS -> T
# TUVWX -> Y
# TU -> V
# O -> P
# RST -> U
# OPQR -> S
# V -> W
# RST -> U
# ABCDE -> F
# R -> S
# XY -> Z
# X -> Y
# VWX -> Y
# JKL -> M
# GHIJK -> L
# G -> H
# FGHIJ -> K
# WXY -> Z
# TUVWX -> Y
# TUVWX -> Y
# RS -> T
# GHI -> J
# VWXY -> Z
# EFGH -> I
# GHIJK -> L
# JKL -> M
# MNO -> P
# WX -> Y
# RST -> U
# R -> S
# UVW -> X
# DEFG -> H
# STUV -> W
# XY -> Z
# L -> M
# P -> Q
# L -> M
# L -> M
# EFGHI -> J
# O -> P
# QRS -> T
# PQRST -> U
# MNOPQ -> R
# P -> Q
# NOP -> Q
# HI -> J
# DEFG -> H
# LMN -> O
# EFG -> H
# T -> U
# DEF -> G
# D -> E
# STU -> V
# H -> I
# G -> H
# S -> T
# STUV -> W
# NOP -> Q
# A -> B
# R -> S
# VWXY -> Z
# D -> E
# CD -> E
# JKLMN -> O
# DEF -> G
# RST -> U
# FG -> H
# JKLMN -> O
# TUVWX -> Y
# T -> U
# PQ -> R
# MNOPQ -> R
# D -> E
# VW -> X
# BCD -> E
# HI -> J
# D -> E
# C -> D
# STUV -> W
# I -> J
# H -> I
# TU -> V
# RST -> U
# TUVWX -> Y
# G -> H
# OPQ -> R
# PQRST -> U
# NOPQR -> S
# MNOP -> Q
# OPQ -> R
# KLM -> N
# XY -> Z
# M -> N
# EFGHI -> J
# ABC -> D
# ABCDE -> F
# KLMN -> O
# VW -> X
# CD -> E
# TU -> V
# ST -> U
# WX -> Y
# OP -> Q
# ST -> U
# EF -> G
# LM -> N
# BCDE -> F
# JKLMN -> O
# L -> M
# JKLM -> N
# ABCDE -> F
# LMNO -> P
# CDE -> F
# RSTUV -> W
# TUVWX -> Y
# JKLM -> N
# V -> W
# KLMN -> O
# WX -> Y
# MNOPQ -> R
# HIJK -> L
# HIJKL -> M
# TUV -> W
# Q -> R
# ABC -> D
# IJKL -> M
# TUVW -> X
# IJKLM -> N
# L -> M
# TU -> V
# OPQRS -> T
# WXY -> Z
# MNO -> P
# CDE -> F
# NO -> P
# TU -> V
# STUVW -> X
# O -> P
# QRSTU -> V
# F -> G
# MNOP -> Q
# HIJK -> L
# WX -> Y
# TUVWX -> Y
# VW -> X
# R -> S
# FG -> H
# RST -> U
# DE -> F
# HIJK -> L
# VWX -> Y
# OPQRS -> T
# TUV -> W
# N -> O
# FGHIJ -> K
# I -> J
# HIJ -> K
# P -> Q
# RSTU -> V
# RSTU -> V
# JKLMN -> O
# PQRST -> U
# NOP -> Q
# QRS -> T
# UVWX -> Y
# OP -> Q
# GHIJ -> K
# STUV -> W
# GHIJ -> K
# J -> K
# GHI -> J
# RS -> T
# STU -> V
# WXY -> Z
# GHI -> J
# B -> C
# EF -> G
# Q -> R
# CDEFG -> H
# HIJ -> K
# STU -> V
# OPQR -> S
# PQRS -> T
# V -> W
# PQR -> S
# WXY -> Z
# Q -> R
# NOPQ -> R
# OPQR -> S
# ABC -> D
# S -> T
# HIJKL -> M
# K -> L
# NOP -> Q
# FGHIJ -> K
# HIJKL -> M
# CDEF -> G
# OPQ -> R
# G -> H
# GHIJK -> L
# CDE -> F
# UVWXY -> Z
# FGHI -> J
# LMNO -> P
# NO -> P
# IJK -> L
# WXY -> Z
# E -> F
# MNOPQ -> R
# W -> X
# B -> C
# S -> T
# QRST -> U
# XY -> Z
# TUV -> W
# X -> Y
# JK -> L
# LMN -> O
# KL -> M
# F -> G
# W -> X
# V -> W
# NOPQ -> R
# VW -> X
# ST -> U
# ABCD -> E
# KLMN -> O
# GHIJ -> K
# PQ -> R
# LM -> N
# JK -> L
# FG -> H
# GHI -> J
# FGH -> I
# MN -> O
# IJKL -> M
# IJKLM -> N
# MN -> O
# LMN -> O
# PQRST -> U
# WXY -> Z
# QRS -> T
# MNOPQ -> R
# QRSTU -> V
# OP -> Q
# ABC -> D
# RST -> U
# RST -> U
# IJKLM -> N
# DE -> F
# LM -> N
# K -> L
# L -> M
# OPQ -> R
# AB -> C
# ABC -> D
# IJKLM -> N
# TUVW -> X
# FGHIJ -> K
# MNOPQ -> R
# EFGHI -> J
# JK -> L
# HIJ -> K
# GHIJ -> K
# STUVW -> X
# GHI -> J
# KL -> M
# DEFG -> H
# RSTUV -> W
# OPQRS -> T
# ABCD -> E
# MN -> O
# GHIJK -> L
# PQ -> R
# UVWX -> Y
# D -> E
# QRS -> T
# W -> X
# HIJKL -> M
# JK -> L
# WXY -> Z
# EFG -> H
# OPQRS -> T
# KLMNO -> P
# M -> N
# UV -> W
# IJ -> K
# D -> E
# A -> B
# QRS -> T
# V -> W
# DE -> F
# BC -> D
# LM -> N
# JK -> L
# R -> S
# JKLMN -> O
# CDE -> F
# PQRST -> U
# KLMN -> O
# DEF -> G
# PQR -> S
# U -> V
# M -> N
# GH -> I
# G -> H
# JKL -> M
# TUV -> W
# FG -> H
# VW -> X
# G -> H
# F -> G
# PQRST -> U
# X -> Y
# D -> E
# IJKLM -> N
# OP -> Q
# EFG -> H
# UVWXY -> Z
# FGHIJ -> K
# I -> J
# STUVW -> X
# GH -> I
# BCDEF -> G
# XY -> Z
# MN -> O
# U -> V
# IJ -> K
# HIJ -> K

# %%
from keras.preprocessing.sequence import *

# %%
X = pad_sequences(dataX, maxlen=max_len, dtype='float32')

# %%
X
# Out:
# array([[  0.,   4.,   5.,   6.,   7.],
#        [  0.,   0.,  18.,  19.,  20.],
#        [  0.,   0.,   0.,  15.,  16.],
#        ...,
#        [  0.,   0.,   0.,   0.,  20.],
#        [  0.,   0.,   0.,   8.,   9.],
#        [  0.,   0.,   7.,   8.,   9.]], dtype=float32)
